# %% [markdown]
# # Introduction

# %%
import requests
from bs4 import BeautifulSoup
import datetime
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# # Import data
#
# I will use each Billboard's top 100 emerging artists list, as published on a weekly basis from 2018 to early 2020, to generate a list of several hundred artists whose tour itineraries I will pull from Songkick.

# %% [markdown]
# ## Scrape list of emerging artists from Billboard
# ### Create list of all dates in 2018, 2019, and early 2020 that fall on a Saturday (for concatenation with URL)

# %%
# SOURCE:  https://stackoverflow.com/questions/993358/creating-a-range-of-dates-in-python
# compile list of every saturday in 2019 and Jan-Feb 2020, in Year-Month-Day format

weeks = []

start = datetime.datetime.strptime("2018-01-06", "%Y-%m-%d")
end = datetime.datetime.strptime("2020-02-29", "%Y-%m-%d")
date_generated = [start + datetime.timedelta(weeks=x) for x in range(0, (end-start).days)]

for date in date_generated:
    weeks.append(date.strftime("%Y-%m-%d"))
    
weeks = weeks[0:113]

# %%
print(weeks[0])
print(weeks[112])
# Out:
# 2018-01-06
# 2020-02-29

# %% [markdown]
# ### Scrape names of top 50 emerging artists for each week in date list, removing duplicates

# %%
artists_scrape = []

for w in weeks:
    url = 'https://www.billboard.com/charts/emerging-artists/' + w
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    artistsoup = soup.find_all('div', class_='item-details__title')
    for a in artistsoup:
        name = a.get_text()
        if name in artists_scrape:
            continue
        else:
            artists_scrape.append(name)

# %%
len(artists_scrape)
# Out:
# 194

# %%
# MANUAL COPY OF ARTIST LIST, WITH KAREN GIBSON REMOVED (HER CHOIR PERFORMANCE AT HARRY AND MEGAN'S WEDDING 
# WENT VIRAL, RESULTING IN HER CHART PLACEMENT ON BILLBOARDS EMERGING ARTISTS LIST)

artistlist = ['LANCO', 'Russell Dickerson', 'MAX', 'Walker Hayes', 'Lil Xan', 'Zacari', 'YBN Nahmir', 'Trippie Redd',
 'Devin Dawson', 'GoldLink', 'Zendaya', 'Jacquees', 'Tay-K', 'Logan Paul', 'Lil Baby', 'Tee Grizzley', 'Lauv',
 'Louis Tomlinson', 'Lil Skies', 'Sofi Tukker', 'Dylan Scott', 'Christian Nodal', 'Big Shaq', 'Alice Merton',
 'Swae Lee', 'High Valley', 'Bhad Bhabie', 'Jordan Davis', 'Anitta', 'Alan Walker', 'Greta Van Fleet', 'Wanna One',
 'The Revivalists', 'AJR', 'YFN Lucci', 'HRVY', 'Famous Dex', 'Carly Pearce', "Auli'i Cravalho", 'Yung Bleu',
 'Natti Natasha', 'Keala Settle', 'TakeOff', 'DeJ Loaf', 'Nego do Borel', 'MONSTA X', 'Loren Allred', 'Sabrina Carpenter',
 'Alta Consigna', "Rag'n'Bone Man", 'The Bellas', 'Blac Youngsta', 'Jeff Rosenstock', 'Andra Day', 'Just Chase',
 'Lexy Panterra', 'Chris Lane', 'watt', 'Morgan Wallen', 'Sebastian Yatra', 'Tauren Wells', 'Nacho', 'Billie Eilish',
 'Rita Ora', 'Watain', 'Layton Greene', "Derez De'Shon", 'Landon Cube', 'Anderson East', 'Avatar', 'Typhoon',
 'Tonight Alive', 'Ansel Elgort', 'Bazzi', 'Ty Tabor', 'GENTRI', 'Rich The Kid', 'EDEN', 'Cane Hill', 'Caleb + Kelsey',
 'tUnE-YaRdS', 'Queen Naija', 'Jason Manns', 'H.E.R.', 'Bad Wolves', 'Bahamas', 'Moon Taxi', 'Cory Asbury', 'Waterparks',
 'Ty Segall', 'Red Velvet', 'Evidence', 'Mike Shinoda', 'Tiny Moving Parts', 'Kali Uchis', 'Sleeping Giant', 'The Dangerous Summer',
 'Madison Beer', 'Rhye', "Why Don't We", 'Bishop Briggs', 'The Wood Brothers', 'Jon Langston', 'SOB X RBE', 'The Wombats',
 'Saudi', 'Good Tiger', 'DJ Kass', 'Jorja Smith', 'Anne-Marie', 'Jordan Feliz', "I'm With Her", 'Car Seat Headrest',
 'Slaves', 'Normani', 'The Plot In You', 'Superchunk', '6LACK', 'American Nightmare', 'Pianos Become The Teeth', 'John Corabi',
 'Agust D', 'j-hope', 'Dessa', 'Turnstile', 'Big Smo', 'Screaming Females', 'Phonte', 'Tracey Thorn', 'Lucius',
 'Calum Scott', 'Titus Andronicus', 'Joyner Lucas', 'Superorganism', 'The Band Of Heathens', 'Moose Blood', 'Trixie Mattel',
 'Stefflon Don', 'lovelytheband', 'PRhyme', 'Adam Calhoun', 'NCT', 'Rich Homie Quan', 'Hot Snakes', 'Ella Mai',
 'Saweetie', 'Rivers Of Nihil', 'Chiquis Rivera', 'DOROTHY', 'Todrick Hall', 'Paul Thorn', 'Dynamite Dylan', 'Lissie',
 'Ashley McBryde', 'Light The Torch', 'The Voidz', 'Gesaffelstein', 'Red Sun Rising', 'King Gizzard And The Lizard Wizard', 'Jukebox The Ghost',
 'Dr. Octagon', 'Allen Stone', 'Hop Along', 'Alina Baraz', 'The Aquabats!', 'Unknown Mortal Orchestra', 'Wye Oak',
 'Poo Bear', 'LEDGER', 'Prof', 'El Chombo', 'Raymix', 'Nekrogoblikon', 'From Ashes To New', 'Drew Love', 'TesseracT',
 'Morgan Evans', 'My Silent Bravery', 'Tammy Rivera', 'Mason Ramsey', 'Pryor Baird', 'Britton Buchanan', 'NCT 127',
 'Stray Kids', 'Frank Turner', 'Trampled By Turtles', 'Shakey Graves', 'Black Moth Super Rainbow', 'Wolfine', 'Juice WRLD',
 'Slim Jxmmi', 'The Word Alive', 'Kyla Jade', 'Drake White', 'Brynn Cartelli', 'Kaleb Lee', 'Brent Cobb', 'Joji',
 'Spensha Baker', 'Lindsay Ell', 'Two Feet', 'Sheku Kanneh-Mason', 'Maddie Poppe', 'Kris Wu', 'Parquet Courts',
 'Iration', 'Dana Fuchs', 'Trent Harmon', 'Caleb Lee Hutchinson', 'Gabby Barrett', 'Gunna', 'Influence Music',
 'Jackson Wang', 'Tyla Yaweh', 'Graveyard', 'Jude Demorest', 'Skepta', 'DJ SPINKING']

# %%
len(artistlist)
# Out:
# 218

# %% [markdown]
# ## Scrape historical live event data, by artist, from Songkick
# ### Format artist list for URL concatenation

# %%
artists = []

for a in artistlist:
    newa = a.replace(' ', '+')
    artists.append(newa)
    
artists
# Out:
# ['LANCO',
#  'Russell+Dickerson',
#  'MAX',
#  'Walker+Hayes',
#  'Lil+Xan',
#  'Zacari',
#  'YBN+Nahmir',
#  'Trippie+Redd',
#  'Devin+Dawson',
#  'GoldLink',
#  'Zendaya',
#  'Jacquees',
#  'Tay-K',
#  'Logan+Paul',
#  'Lil+Baby',
#  'Tee+Grizzley',
#  'Lauv',
#  'Louis+Tomlinson',
#  'Lil+Skies',
#  'Sofi+Tukker',
#  'Dylan+Scott',
#  'Christian+Nodal',
#  'Big+Shaq',
#  'Alice+Merton',
#  'Swae+Lee',
#  'High+Valley',
#  'Bhad+Bhabie',
#  'Jordan+Davis',
#  'Anitta',
#  'Alan+Walker',
#  'Greta+Van+Fleet',
#  'Wanna+One',
#  'The+Revivalists',
#  'AJR',
#  'YFN+Lucci',
#  'HRVY',
#  'Famous+Dex',
#  'Carly+Pearce',
#  "Auli'i+Cravalho",
#  'Yung+Bleu',
#  'Natti+Natasha',
#  'Keala+Settle',
#  'TakeOff',
#  'DeJ+Loaf',
#  'Nego+do+Borel',
#  'MONSTA+X',
#  'Loren+Allred',
#  'Sabrina+Carpenter',
#  'Alta+Consigna',
#  "Rag'n'Bone+Man",
#  'The+Bellas',
#  'Blac+Youngsta',
#  'Jeff+Rosenstock',
#  'Andra+Day',
#  'Just+Chase',
#  'Lexy+Panterra',
#  'Chris+Lane',
#  'watt',
#  'Morgan+Wallen',
#  'Sebastian+Yatra',
#  'Tauren+Wells',
#  'Nacho',
#  'Billie+Eilish',
#  'Rita+Ora',
#  'Watain',
#  'Layton+Greene',
#  "Derez+De'Shon",
#  'Landon+Cube',
#  'Anderson+East',
#  'Avatar',
#  'Typhoon',
#  'Tonight+Alive',
#  'Ansel+Elgort',
#  'Bazzi',
#  'Ty+Tabor',
#  'GENTRI',
#  'Rich+The+Kid',
#  'EDEN',
#  'Cane+Hill',
#  'Caleb+++Kelsey',
#  'tUnE-YaRdS',
#  'Queen+Naija',
#  'Jason+Manns',
#  'H.E.R.',
#  'Bad+Wolves',
#  'Bahamas',
#  'Moon+Taxi',
#  'Cory+Asbury',
#  'Waterparks',
#  'Ty+Segall',
#  'Red+Velvet',
#  'Evidence',
#  'Mike+Shinoda',
#  'Tiny+Moving+Parts',
#  'Kali+Uchis',
#  'Sleeping+Giant',
#  'The+Dangerous+Summer',
#  'Madison+Beer',
#  'Rhye',
#  "Why+Don't+We",
#  'Bishop+Briggs',
#  'The+Wood+Brothers',
#  'Jon+Langston',
#  'SOB+X+RBE',
#  'The+Wombats',
#  'Saudi',
#  'Good+Tiger',
#  'DJ+Kass',
#  'Jorja+Smith',
#  'Anne-Marie',
#  'Jordan+Feliz',
#  "I'm+With+Her",
#  'Car+Seat+Headrest',
#  'Slaves',
#  'Normani',
#  'The+Plot+In+You',
#  'Superchunk',
#  '6LACK',
#  'American+Nightmare',
#  'Pianos+Become+The+Teeth',
#  'John+Corabi',
#  'Agust+D',
#  'j-hope',
#  'Dessa',
#  'Turnstile',
#  'Big+Smo',
#  'Screaming+Females',
#  'Phonte',
#  'Tracey+Thorn',
#  'Lucius',
#  'Calum+Scott',
#  'Titus+Andronicus',
#  'Joyner+Lucas',
#  'Superorganism',
#  'The+Band+Of+Heathens',
#  'Moose+Blood',
#  'Trixie+Mattel',
#  'Stefflon+Don',
#  'lovelytheband',
#  'PRhyme',
#  'Adam+Calhoun',
#  'NCT',
#  'Rich+Homie+Quan',
#  'Hot+Snakes',
#  'Ella+Mai',
#  'Saweetie',
#  'Rivers+Of+Nihil',
#  'Chiquis+Rivera',
#  'DOROTHY',
#  'Todrick+Hall',
#  'Paul+Thorn',
#  'Dynamite+Dylan',
#  'Lissie',
#  'Ashley+McBryde',
#  'Light+The+Torch',
#  'The+Voidz',
#  'Gesaffelstein',
#  'Red+Sun+Rising',
#  'King+Gizzard+And+The+Lizard+Wizard',
#  'Jukebox+The+Ghost',
#  'Dr.+Octagon',
#  'Allen+Stone',
#  'Hop+Along',
#  'Alina+Baraz',
#  'The+Aquabats!',
#  'Unknown+Mortal+Orchestra',
#  'Wye+Oak',
#  'Poo+Bear',
#  'LEDGER',
#  'Prof',
#  'El+Chombo',
#  'Raymix',
#  'Nekrogoblikon',
#  'From+Ashes+To+New',
#  'Drew+Love',
#  'TesseracT',
#  'Morgan+Evans',
#  'My+Silent+Bravery',
#  'Tammy+Rivera',
#  'Mason+Ramsey',
#  'Pryor+Baird',
#  'Britton+Buchanan',
#  'NCT+127',
#  'Stray+Kids',
#  'Frank+Turner',
#  'Trampled+By+Turtles',
#  'Shakey+Graves',
#  'Black+Moth+Super+Rainbow',
#  'Wolfine',
#  'Juice+WRLD',
#  'Slim+Jxmmi',
#  'The+Word+Alive',
#  'Kyla+Jade',
#  'Drake+White',
#  'Brynn+Cartelli',
#  'Kaleb+Lee',
#  'Brent+Cobb',
#  'Joji',
#  'Spensha+Baker',
#  'Lindsay+Ell',
#  'Two+Feet',
#  'Sheku+Kanneh-Mason',
#  'Maddie+Poppe',
#  'Kris+Wu',
#  'Parquet+Courts',
#  'Iration',
#  'Dana+Fuchs',
#  'Trent+Harmon',
#  'Caleb+Lee+Hutchinson',
#  'Gabby+Barrett',
#  'Gunna',
#  'Influence+Music',
#  'Jackson+Wang',
#  'Tyla+Yaweh',
#  'Graveyard',
#  'Jude+Demorest',
#  'Skepta',
#  'DJ+SPINKING']

# %% [markdown]
# ### Create function that scrapes Songkick for past events of a single artist

# %%
def pull_events(artist):

    eventslist = []

    for n in range(1,21):
        url = 'https://www.songkick.com/search?page='+str(n)+'&per_page=10&query='+artist+'&type=past'
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')

        events = soup.find_all('li', class_='concert event')
        for e in events:
            date = e.find('time').get_text()
            location = e.find('p', class_='location').get_text()
            tup = (artist, date, location)
            eventslist.append(tup)
    
    return eventslist

# %% [markdown]
# ### Loop scraping function to compile historical events for all emerging artists in our list

# %%
allevents = []
for a in artists:
    artistevents = pull_events(a)
    allevents.append(artistevents)
    print(a)
# Out:
# LANCO
# Russell+Dickerson
# MAX
# Walker+Hayes
# Lil+Xan
# Zacari
# YBN+Nahmir
# Trippie+Redd
# Devin+Dawson
# GoldLink
# Zendaya
# Jacquees
# Tay-K
# Logan+Paul
# Lil+Baby
# Tee+Grizzley
# Lauv
# Louis+Tomlinson
# Lil+Skies
# Sofi+Tukker
# Dylan+Scott
# Christian+Nodal
# Big+Shaq
# Alice+Merton
# Swae+Lee
# High+Valley
# Bhad+Bhabie
# Jordan+Davis
# Anitta
# Alan+Walker
# Greta+Van+Fleet
# Wanna+One
# The+Revivalists
# AJR
# YFN+Lucci
# HRVY
# Famous+Dex
# Carly+Pearce
# Auli'i+Cravalho
# Yung+Bleu
# Natti+Natasha
# Keala+Settle
# TakeOff
# DeJ+Loaf
# Nego+do+Borel
# MONSTA+X
# Loren+Allred
# Sabrina+Carpenter
# Alta+Consigna
# Rag'n'Bone+Man
# The+Bellas
# Blac+Youngsta
# Jeff+Rosenstock
# Andra+Day
# Just+Chase
# Lexy+Panterra
# Chris+Lane
# watt
# Morgan+Wallen
# Sebastian+Yatra
# Tauren+Wells
# Nacho
# Billie+Eilish
# Rita+Ora
# Watain
# Layton+Greene
# Derez+De'Shon
# Landon+Cube
# Anderson+East
# Avatar
# Typhoon
# Tonight+Alive
# Ansel+Elgort
# Bazzi
# Ty+Tabor
# GENTRI
# Rich+The+Kid
# EDEN
# Cane+Hill
# Caleb+++Kelsey
# tUnE-YaRdS
# Queen+Naija
# Jason+Manns
# H.E.R.
# Bad+Wolves
# Bahamas
# Moon+Taxi
# Cory+Asbury
# Waterparks
# Ty+Segall
# Red+Velvet
# Evidence
# Mike+Shinoda
# Tiny+Moving+Parts
# Kali+Uchis
# Sleeping+Giant
# The+Dangerous+Summer
# Madison+Beer
# Rhye
# Why+Don't+We
# Bishop+Briggs
# The+Wood+Brothers
# Jon+Langston
# SOB+X+RBE
# The+Wombats
# Saudi
# Good+Tiger
# DJ+Kass
# Jorja+Smith
# Anne-Marie
# Jordan+Feliz
# I'm+With+Her
# Car+Seat+Headrest
# Slaves
# Normani
# The+Plot+In+You
# Superchunk
# 6LACK
# American+Nightmare
# Pianos+Become+The+Teeth
# John+Corabi
# Agust+D
# j-hope
# Dessa
# Turnstile
# Big+Smo
# Screaming+Females
# Phonte
# Tracey+Thorn
# Lucius
# Calum+Scott
# Titus+Andronicus
# Joyner+Lucas
# Superorganism
# The+Band+Of+Heathens
# Moose+Blood
# Trixie+Mattel
# Stefflon+Don
# lovelytheband
# PRhyme
# Adam+Calhoun
# NCT
# Rich+Homie+Quan
# Hot+Snakes
# Ella+Mai
# Saweetie
# Rivers+Of+Nihil
# Chiquis+Rivera
# DOROTHY
# Todrick+Hall
# Paul+Thorn
# Dynamite+Dylan
# Lissie
# Ashley+McBryde
# Light+The+Torch
# The+Voidz
# Gesaffelstein
# Red+Sun+Rising
# King+Gizzard+And+The+Lizard+Wizard
# Jukebox+The+Ghost
# Dr.+Octagon
# Allen+Stone
# Hop+Along
# Alina+Baraz
# The+Aquabats!
# Unknown+Mortal+Orchestra
# Wye+Oak
# Poo+Bear
# LEDGER
# Prof
# El+Chombo
# Raymix
# Nekrogoblikon
# From+Ashes+To+New
# Drew+Love
# TesseracT
# Morgan+Evans
# My+Silent+Bravery
# Tammy+Rivera
# Mason+Ramsey
# Pryor+Baird
# Britton+Buchanan
# NCT+127
# Stray+Kids
# Frank+Turner
# Trampled+By+Turtles
# Shakey+Graves
# Black+Moth+Super+Rainbow
# Wolfine
# Juice+WRLD
# Slim+Jxmmi
# The+Word+Alive
# Kyla+Jade
# Drake+White
# Brynn+Cartelli
# Kaleb+Lee
# Brent+Cobb
# Joji
# Spensha+Baker
# Lindsay+Ell
# Two+Feet
# Sheku+Kanneh-Mason
# Maddie+Poppe
# Kris+Wu
# Parquet+Courts
# Iration
# Karen+Gibson+&+The+Kingdom+Choir
# Dana+Fuchs
# Trent+Harmon
# Caleb+Lee+Hutchinson
# Gabby+Barrett
# Gunna
# Influence+Music
# Jackson+Wang
# Tyla+Yaweh
# Graveyard
# Jude+Demorest
# Skepta
# DJ+SPINKING

# %% [markdown]
# ### Preliminary cleaning before saving data locally

# %%
# LIST IS CURRENTLY GROUPED BY EACH ARTIST; WE NEED EACH EVENT TO BE ITS OWN ROW

len(allevents)
# Out:
# 219

# %%
# UNRAVELING THE LIST TO MAKE EACH EVENT FOR EACH ARTIST ITS OWN ROW

allevents_long = []
for i in allevents:
    for j in i:
        allevents_long.append(j)

# %%
len(allevents_long)
# Out:
# 26476

# %%
df = pd.DataFrame(allevents_long)
df.head()
# Out:
#        0                          1  \
# 0  LANCO  Wednesday 16 January 2019
# 1  LANCO     Friday 18 January 2019
# 2  LANCO       Friday 13 March 2020
# 3  LANCO   Saturday 19 January 2019
# 4  LANCO  Saturday 15 February 2020
#
#                                                    2
# 0    \n      The Depot, Salt Lake City, UT, US\n
# 1        \n      Showbox SoDo, Seattle, WA, US\n
# 2  \n      Joe's Live Rosemont, Rosemont, IL, US\...
# 3    \n      Wonder Ballroom, Portland, OR, US\n
# 4          \n      Bluestone, Columbus, OH, US\n

# %%
# SAVING DATAFRAME AS A CSV FILE 

df.to_csv('data/scrape_long.csv', index=False)

# %%
df = pd.read_csv('data/scrape_long.csv')

# %%
df.rename(columns={'0':'artist', '1':'date', '2':'location'}, inplace=True)
df.head()
# Out:
#   artist                       date  \
# 0  LANCO  Wednesday 16 January 2019
# 1  LANCO     Friday 18 January 2019
# 2  LANCO       Friday 13 March 2020
# 3  LANCO   Saturday 19 January 2019
# 4  LANCO  Saturday 15 February 2020
#
#                                             location
# 0    \n      The Depot, Salt Lake City, UT, US\n
# 1        \n      Showbox SoDo, Seattle, WA, US\n
# 2  \n      Joe's Live Rosemont, Rosemont, IL, US\...
# 3    \n      Wonder Ballroom, Portland, OR, US\n
# 4          \n      Bluestone, Columbus, OH, US\n

# %% [markdown]
# ## Pull artist genre classifiers from Spotify API

# %%
auth_manager = SpotifyClientCredentials(client_id='ea51f4db67cf4a808dde1a9851ccd19e', 
                                        client_secret='048f383d092747fe8b9d3aa6914f0a3c')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# ### Retrieve artist URI codes

# %%
# Query spotipy for all artist URI codes

uri_list = []

for a in artistlist:
    result = sp.search(a)
    try:
        artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
        uri_list.append(artist_uri)
    except:
        print(a)
        pass
# Out:
# Karen Gibson & The Kingdom Choir

# %%
len(uri_list)
# Out:
# 218

# %% [markdown]
# ### Retrieve artist genres using URI codes

# %%
# Use artist URI codes to query spotipy for each artist's associated genres

genrelist = []

for u in uri_list:
    genres = sp.artist(u)['genres']
    genrelist.append(genres)

# %%
len(genrelist)
# Out:
# 218

# %%
d = {'artist':artists, 'genre':genrelist}
genre_df = pd.DataFrame(d)
genre_df.head()
# Out:
#               artist                                              genre
# 0              LANCO                [contemporary country, country pop]
# 1  Russell+Dickerson  [contemporary country, country, country road, ...
# 2                MAX  [dance pop, electropop, pop, post-teen pop, vi...
# 3       Walker+Hayes  [contemporary country, country, country pop, c...
# 4            Lil+Xan                     [emo rap, underground hip hop]

# %%
genre_df
# Out:
#                 artist                                              genre
# 0                LANCO                [contemporary country, country pop]
# 1    Russell+Dickerson  [contemporary country, country, country road, ...
# 2                  MAX  [dance pop, electropop, pop, post-teen pop, vi...
# 3         Walker+Hayes  [contemporary country, country, country pop, c...
# 4              Lil+Xan                     [emo rap, underground hip hop]
# ..                 ...                                                ...
# 213         Tyla+Yaweh        [cali rap, melodic rap, pop rap, rap, trap]
# 214          Graveyard  [dance pop, electropop, etherpop, indie poptim...
# 215      Jude+Demorest     [pop, pop r&b, post-teen pop, r&b, trap queen]
# 216             Skepta                       [hip hop, ohio hip hop, rap]
# 217        DJ+SPINKING                  [melodic rap, pop rap, rap, trap]
#
# [218 rows x 2 columns]

# %%
genrelist
# Out:
# [['contemporary country', 'country pop'],
#  ['contemporary country', 'country', 'country road', 'modern country rock'],
#  ['dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop'],
#  ['contemporary country',
#   'country',
#   'country pop',
#   'country road',
#   'modern country rock'],
#  ['emo rap', 'underground hip hop'],
#  ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#  ['alabama rap', 'pop rap', 'rap', 'trap', 'vapor trap', 'viral rap'],
#  ['emo rap', 'miami hip hop'],
#  ['contemporary country', 'country pop', 'modern country rock'],
#  ['alternative r&b',
#   'dmv rap',
#   'hip hop',
#   'indie soul',
#   'r&b',
#   'rap',
#   'underground hip hop'],
#  ['underground hip hop'],
#  ['atl hip hop',
#   'pop',
#   'pop r&b',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary'],
#  ['cali rap', 'dfw rap', 'rap', 'trap', 'underground hip hop', 'vapor trap'],
#  ['social media pop'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['detroit hip hop',
#   'detroit trap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['electropop', 'pop', 'post-teen pop'],
#  ['pop', 'post-teen pop'],
#  ['melodic rap', 'pop rap', 'rap', 'trap'],
#  ['electropop'],
#  ['contemporary country', 'country', 'country road', 'modern country rock'],
#  ['mariachi', 'nuevo regional mexicano', 'ranchera', 'regional mexican'],
#  ['london rap'],
#  [],
#  ['contemporary country', 'country', 'country road'],
#  ['alberta country',
#   'canadian contemporary country',
#   'canadian country',
#   'contemporary country',
#   'country',
#   'country pop',
#   'country road',
#   'modern country rock'],
#  ['pop', 'pop rap', 'social media pop', 'trap queen', 'viral rap'],
#  ['contemporary country'],
#  ['funk carioca', 'funk pop', 'pagode baiano', 'pop nacional'],
#  ['electro house', 'pop dance'],
#  ['modern blues rock', 'modern hard rock', 'rock'],
#  ['k-pop', 'k-pop boy group'],
#  ['indie folk',
#   'modern alternative rock',
#   'modern rock',
#   'rock',
#   'stomp and holler'],
#  ['modern rock'],
#  ['arkansas hip hop',
#   'atl hip hop',
#   'melodic rap',
#   'pop r&b',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['dance pop', 'indie cafe pop', 'pop', 'post-teen pop', 'social media pop'],
#  ['chicago rap',
#   'drill',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'underground hip hop',
#   'vapor trap',
#   'viral rap'],
#  ['contemporary country', 'country pop'],
#  ['disney', 'hollywood', 'movie tunes', 'show tunes'],
#  ['alabama rap', 'pop r&b', 'trap'],
#  ['latin', 'latin pop', 'rap latina', 'reggaeton', 'trap latino', 'tropical'],
#  ['broadway', 'hollywood', 'show tunes'],
#  ['atl hip hop', 'rap', 'southern hip hop', 'trap', 'vapor trap'],
#  ['detroit hip hop', 'pop r&b', 'pop rap', 'r&b', 'rap', 'trap', 'trap queen'],
#  ['latin', 'reggaeton', 'reggaeton colombiano'],
#  ['k-pop', 'k-pop boy group'],
#  ['deep talent show', 'hollywood', 'movie tunes'],
#  ['alt z', 'dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop'],
#  ['corrido',
#   'corridos tumbados',
#   'nuevo regional mexicano',
#   'regional mexican',
#   'sierreno'],
#  ['neo soul'],
#  ['hollywood', 'movie tunes'],
#  ['hip hop', 'rap', 'southern hip hop', 'tennessee hip hop', 'trap'],
#  ['alternative emo',
#   'anti-folk',
#   'bubblegrunge',
#   'folk punk',
#   'indie punk',
#   'indie rock',
#   'modern power pop',
#   'modern rock'],
#  ['neo soul', 'r&b'],
#  ['canadian hip hop',
#   'canadian old school hip hop',
#   'indie pop rap',
#   'pop rap'],
#  [],
#  ['contemporary country', 'country road', 'modern country rock'],
#  [],
#  ['contemporary country', 'deep talent show'],
#  ['colombian pop',
#   'latin',
#   'latin pop',
#   'reggaeton',
#   'reggaeton colombiano',
#   'trap latino'],
#  ['anthem worship',
#   'ccm',
#   'christian music',
#   'christian pop',
#   'world worship'],
#  ['colombian pop',
#   'latin',
#   'latin pop',
#   'reggaeton',
#   'reggaeton colombiano',
#   'trap latino'],
#  ['electropop', 'pop'],
#  ['australian hip hop',
#   'dance pop',
#   'hip pop',
#   'pop',
#   'pop rap',
#   'post-teen pop'],
#  ['black metal',
#   'dark black metal',
#   'metal',
#   'swedish black metal',
#   'swedish metal'],
#  ['hip hop',
#   'melodic rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'vapor trap'],
#  [],
#  ['melodic rap', 'pop rap', 'rap', 'trap'],
#  ['indie folk', 'modern blues', 'new americana'],
#  ['dfw rap'],
#  ['brighton indie',
#   'garage rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern hard rock',
#   'modern rock',
#   'rock'],
#  ['candy pop', 'neon pop punk', 'pixie', 'pop emo', 'pop punk'],
#  ['dance pop', 'post-teen pop'],
#  ['dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop'],
#  [],
#  ['wave'],
#  ['atl hip hop',
#   'hip hop',
#   'melodic rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['dmv rap', 'pop', 'r&b', 'rap'],
#  ['metalcore', 'nu-metalcore'],
#  ['ccm', 'christian alternative rock', 'christian music', 'viral pop'],
#  ['art pop',
#   'escape room',
#   'experimental pop',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'new rave',
#   'one-person band',
#   'stomp and holler'],
#  ['dance pop', 'pop', 'pop r&b', 'r&b', 'urban contemporary'],
#  [],
#  ['alternative r&b', 'dance pop', 'pop', 'r&b', 'urban contemporary'],
#  ['alternative metal', 'metal'],
#  ['canadian indie',
#   'indie folk',
#   'indie pop',
#   'new americana',
#   'stomp and holler'],
#  ['indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler'],
#  ['anthem worship',
#   'ccm',
#   'christian music',
#   'deep ccm',
#   'world worship',
#   'worship'],
#  ['alt z',
#   'modern alternative rock',
#   'modern rock',
#   'neon pop punk',
#   'pixie',
#   'pop punk',
#   'rock',
#   'texas pop punk'],
#  ['alternative rock',
#   'australian garage punk',
#   'bay area indie',
#   'blues rock',
#   'freak folk',
#   'garage pop',
#   'garage psych',
#   'garage rock',
#   'indie garage rock',
#   'indie rock',
#   'modern rock',
#   'neo-psychedelic',
#   'noise pop',
#   'nu gaze',
#   'oc indie',
#   'punk blues'],
#  ['k-pop', 'k-pop girl group'],
#  ['anthem worship', 'ccm', 'deep ccm', 'world worship'],
#  ['alternative hip hop', 'modern rock', 'rap rock'],
#  ['alternative emo', 'anthem emo', 'emo', 'midwest emo'],
#  ['colombian pop', 'pop'],
#  [],
#  ['alternative emo',
#   'anthem emo',
#   'modern alternative rock',
#   'neon pop punk',
#   'pop emo',
#   'pop punk'],
#  ['alt z', 'dance pop', 'electropop', 'pop', 'post-teen pop'],
#  ['downtempo', 'indie soul', 'indietronica', 'shimmer pop'],
#  ['contemporary country', 'country', 'country road', 'modern country rock'],
#  ['electropop', 'modern alternative rock', 'modern rock', 'pop'],
#  ['blues rock',
#   'deep new americana',
#   'funk',
#   'jam band',
#   'new americana',
#   'progressive bluegrass',
#   'roots rock',
#   'stomp and holler'],
#  ['contemporary country',
#   'country pop',
#   'country road',
#   'modern country rock'],
#  ['cali rap', 'trap', 'vapor trap'],
#  ['indie rock',
#   'liverpool indie',
#   'modern alternative rock',
#   'modern rock',
#   'rock'],
#  ['gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'underground hip hop'],
#  ['djent', 'progressive post-hardcore'],
#  ['chilean hardcore'],
#  ['alternative r&b', 'dance pop', 'pop', 'r&b', 'uk contemporary r&b'],
#  ['dance pop',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house',
#   'uk pop'],
#  ['ccm', 'christian hip hop', 'christian trap'],
#  ['folk', 'indie folk', 'new americana', 'progressive bluegrass'],
#  ['alternative rock', 'indie pop', 'indie rock', 'modern rock'],
#  [],
#  ['dance pop', 'pop', 'post-teen pop', 'uk pop'],
#  ['melodic metalcore', 'metalcore', 'post-screamo'],
#  ['alternative pop',
#   'alternative rock',
#   'emo',
#   'freak folk',
#   'gbvfi',
#   'indie punk',
#   'indie rock',
#   'lo-fi',
#   'modern power pop',
#   'noise pop',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'triangle indie'],
#  ['brooklyn drill', 'melodic rap', 'nyc rap'],
#  ['melodic metalcore', 'metalcore', 'post-screamo', 'screamo'],
#  ['alternative emo',
#   'anthem emo',
#   'dreamo',
#   'emo',
#   'melodic hardcore',
#   'midwest emo',
#   'progressive post-hardcore',
#   'screamo'],
#  [],
#  ['k-rap'],
#  ['k-pop', 'k-rap'],
#  ['abstract hip hop', 'hip pop', 'minnesota hip hop', 'underground rap'],
#  ['nordic soundtrack', 'scorecore', 'soundtrack'],
#  ['australian reggae fusion'],
#  ['bubblegrunge',
#   'indie punk',
#   'new jersey hardcore',
#   'new jersey indie',
#   'riot grrrl'],
#  ['hip hop', 'pittsburgh rap', 'rap'],
#  ['downtempo', 'electronica', 'nu jazz', 'trip hop'],
#  ['indie folk', 'indie pop', 'new americana', 'stomp and holler'],
#  ['indie cafe pop', 'pop', 'viral pop'],
#  ['freak folk', 'indie punk', 'indie rock', 'lo-fi', 'new jersey indie'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['art pop'],
#  ['austin americana',
#   'modern southern rock',
#   'new americana',
#   'roots americana',
#   'roots rock',
#   'texas country'],
#  ['alternative emo', 'anthem emo', 'kent indie', 'modern alternative rock'],
#  ['queer country', 'strut'],
#  ['latin', 'latin pop', 'puerto rican pop', 'tropical'],
#  ['indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock'],
#  ['alternative hip hop', 'detroit hip hop'],
#  ['country rap', 'military rap', 'redneck'],
#  ['k-pop', 'k-pop boy group'],
#  ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['dance-punk', 'indie punk', 'indie rock', 'post-hardcore'],
#  ['dance pop',
#   'pop',
#   'pop r&b',
#   'pop rap',
#   'post-teen pop',
#   'r&b',
#   'rap',
#   'uk contemporary r&b',
#   'urban contemporary'],
#  ['cali rap',
#   'dance pop',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'r&b',
#   'trap queen'],
#  ['technical death metal'],
#  ['nuevo regional mexicano'],
#  ['indie garage rock', 'indie pop', 'liverpool indie', 'modern rock'],
#  ['dance pop', 'pop', 'pop rap', 'post-teen pop'],
#  ['roots rock', 'texas country'],
#  ['social media pop'],
#  ['edm',
#   'electro house',
#   'pop dance',
#   'pop edm',
#   'progressive electro house',
#   'progressive house'],
#  ['arkansas country', 'contemporary country', 'country', 'country pop'],
#  ['metalcore'],
#  ['modern alternative rock'],
#  ['dark clubbing', 'destroy techno', 'electro house'],
#  ['alternative metal', 'modern hard rock'],
#  ['australian indie',
#   'australian psych',
#   'double drumming',
#   'neo-psychedelic'],
#  ['indie pop',
#   'indie poptimism',
#   'indiecoustica',
#   'modern alternative rock',
#   'modern rock',
#   'piano rock',
#   'pop rock',
#   'stomp and holler'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'bronx hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'turntablism'],
#  ['retro soul'],
#  [],
#  ['alternative r&b',
#   'chill r&b',
#   'electropop',
#   'etherpop',
#   'pop',
#   'post-teen pop',
#   'r&b'],
#  ['comic', 'modern ska punk', 'punk', 'ska', 'ska punk'],
#  ['chillwave',
#   'indie pop',
#   'indie rock',
#   'indie soul',
#   'kiwi rock',
#   'neo-psychedelic',
#   'new rave',
#   'portland hip hop',
#   'psychedelic pop'],
#  ['art pop',
#   'baltimore indie',
#   'dream pop',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'shimmer pop',
#   'stomp and holler'],
#  ['brostep', 'complextro', 'edm', 'electro', 'pop dance'],
#  ['alternative ccm', 'ccm', 'christian alternative rock', 'christian rock'],
#  ['comedy rap', 'pop rap', 'rap'],
#  ['latin', 'latin hip hop', 'panamanian pop', 'reggaeton', 'tropical'],
#  ['nu-cumbia', 'regional mexican'],
#  ['folk metal', 'viking metal'],
#  ['alternative metal', 'gymcore', 'post-screamo', 'rap rock'],
#  ['edm', 'electropop', 'indie poptimism', 'pop', 'tropical house'],
#  ['djent', 'progressive metal'],
#  ['australian country', 'australian pop', 'contemporary country'],
#  ['worcester ma indie'],
#  ['pop r&b'],
#  ['contemporary country', 'country'],
#  [],
#  ['australian talent show', 'deep talent show'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['acoustic rock', 'folk punk'],
#  ['bluegrass',
#   'deep new americana',
#   'duluth indie',
#   'indie folk',
#   'jam band',
#   'new americana',
#   'progressive bluegrass',
#   'roots rock',
#   'stomp and holler'],
#  ['austin americana',
#   'austindie',
#   'deep new americana',
#   'indie folk',
#   'new americana',
#   'stomp and holler'],
#  ['chillwave', 'freak folk', 'neo-psychedelic'],
#  ['colombian pop', 'latin', 'reggaeton', 'trap latino'],
#  ['chicago rap', 'melodic rap'],
#  ['atl hip hop',
#   'dirty south rap',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['melodic metalcore', 'metalcore', 'post-screamo', 'screamo', 'trancecore'],
#  ['australian talent show'],
#  ['contemporary country'],
#  ['asbury park indie', 'australian talent show'],
#  [],
#  ['indie folk', 'modern southern rock', 'new americana', 'roots americana'],
#  ['alternative r&b', 'viral pop'],
#  ['praise'],
#  ['alberta country',
#   'canadian contemporary country',
#   'canadian country',
#   'contemporary country',
#   'country pop'],
#  ['indie poptimism', 'modern rock', 'pop'],
#  ['sleep'],
#  [],
#  ['chinese hip hop', 'chinese idol pop'],
#  ['alternative rock',
#   'brooklyn indie',
#   'denton tx indie',
#   'freak folk',
#   'garage psych',
#   'indie garage rock',
#   'indie rock',
#   'modern alternative rock',
#   'modern rock',
#   'neo-psychedelic',
#   'noise pop'],
#  ['jawaiian', 'reggae rock'],
#  ['hollywood'],
#  ['arkansas country'],
#  [],
#  ['contemporary country', 'country pop'],
#  ['pop rap', 'rap', 'trap'],
#  ['anthem worship', 'ccm', 'christian pop', 'world worship'],
#  ['hong kong hip hop', 'k-pop'],
#  ['cali rap', 'melodic rap', 'pop rap', 'rap', 'trap'],
#  ['dance pop',
#   'electropop',
#   'etherpop',
#   'indie poptimism',
#   'pop',
#   'post-teen pop'],
#  ['pop', 'pop r&b', 'post-teen pop', 'r&b', 'trap queen'],
#  ['hip hop', 'ohio hip hop', 'rap'],
#  ['melodic rap', 'pop rap', 'rap', 'trap']]

# %% [markdown]
# ### Manual assignment of single genre to each artist

# %%
genre1 = ['country', 'country', 'pop', 'country', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'country', 'hiphop', 'hiphop',
 'hiphop', 'hiphop', 'pop', 'hiphop', 'hiphop', 'pop', 'pop', 'hiphop', 'pop', 'country', 'latin', 'hiphop',
 'blank', 'country', 'country', 'pop', 'country', 'latin', 'pop', 'rock', 'pop', 'rock', 'rock', 'hiphop', 'pop',
 'hiphop', 'country', 'blank', 'hiphop', 'latin', 'blank', 'hiphop', 'hiphop', 'latin', 'pop', 'blank', 'pop',
 'latin', 'hiphop', 'blank', 'hiphop', 'rock', 'hiphop', 'hiphop', 'blank', 'country', 'blank', 'country',
 'latin', 'faith', 'latin', 'pop', 'hiphop', 'rock', 'hiphop', 'blank', 'hiphop', 'rock', 'hiphop', 'rock', 'pop',
 'pop', 'pop', 'blank', 'blank', 'hiphop', 'hiphop', 'rock', 'faith', 'pop', 'pop', 'blank', 'pop', 'rock', 'rock',
 'rock', 'faith', 'rock', 'rock', 'pop', 'faith', 'hiphop', 'rock', 'latin', 'blank', 'rock', 'pop', 'hiphop',
 'country', 'pop', 'rock', 'country', 'hiphop', 'rock', 'hiphop', 'rock', 'latin', 'pop', 'pop', 'faith', 'rock',
 'rock', 'blank', 'pop', 'rock', 'pop', 'hiphop', 'rock', 'rock', 'blank', 'hiphop', 'pop', 'hiphop', 'blank',
 'rock', 'rock', 'hiphop', 'hiphop', 'pop', 'pop', 'rock', 'hiphop', 'pop', 'rock', 'rock', 'country', 'latin', 'pop',
 'hiphop', 'hiphop', 'pop', 'hiphop', 'rock', 'pop', 'hiphop', 'rock', 'latin', 'rock', 'pop', 'country', 'pop',
 'pop', 'country', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'hiphop', 'hiphop', 'blank', 'pop', 'rock',
 'hiphop', 'pop', 'pop', 'faith', 'hiphop', 'latin', 'latin', 'rock', 'rock', 'pop', 'rock', 'country', 'rock',
 'hiphop', 'country', 'blank', 'blank', 'pop', 'pop', 'rock', 'rock', 'rock', 'hiphop', 'latin', 'hiphop', 'hiphop',
 'rock', 'blank', 'country', 'blank', 'blank', 'rock', 'hiphop', 'faith', 'country', 'pop', 'blank', 'blank', 'hiphop',
 'rock', 'rock', 'blank', 'country', 'blank', 'country', 'hiphop', 'faith', 'pop', 'hiphop', 'pop', 'pop',
 'hiphop', 'hiphop']

# %%
genre1 = pd.DataFrame(genre1)
genre1_df = pd.concat([genre_df, genre1], axis=1)
genre1_df.head()
# Out:
#               artist                                              genre  \
# 0              LANCO                [contemporary country, country pop]
# 1  Russell+Dickerson  [contemporary country, country, country road, ...
# 2                MAX  [dance pop, electropop, pop, post-teen pop, vi...
# 3       Walker+Hayes  [contemporary country, country, country pop, c...
# 4            Lil+Xan                     [emo rap, underground hip hop]
#
#          0
# 0  country
# 1  country
# 2      pop
# 3  country
# 4   hiphop

# %%
genre1_df.rename(columns={'genre':'genre_complex', 0:'genre'}, inplace=True)
genre1_df.head()
# Out:
#               artist                                      genre_complex  \
# 0              LANCO                [contemporary country, country pop]
# 1  Russell+Dickerson  [contemporary country, country, country road, ...
# 2                MAX  [dance pop, electropop, pop, post-teen pop, vi...
# 3       Walker+Hayes  [contemporary country, country, country pop, c...
# 4            Lil+Xan                     [emo rap, underground hip hop]
#
#      genre
# 0  country
# 1  country
# 2      pop
# 3  country
# 4   hiphop

# %%
# Dropping approx 20 artists from the list who didn't fit into the final set of mainstream genre groupings

df_gen = genre1_df[genre1_df['genre'] != 'blank']

# %%
df_gen
# Out:
#                 artist                                      genre_complex  \
# 0                LANCO                [contemporary country, country pop]
# 1    Russell+Dickerson  [contemporary country, country, country road, ...
# 2                  MAX  [dance pop, electropop, pop, post-teen pop, vi...
# 3         Walker+Hayes  [contemporary country, country, country pop, c...
# 4              Lil+Xan                     [emo rap, underground hip hop]
# ..                 ...                                                ...
# 213         Tyla+Yaweh        [cali rap, melodic rap, pop rap, rap, trap]
# 214          Graveyard  [dance pop, electropop, etherpop, indie poptim...
# 215      Jude+Demorest     [pop, pop r&b, post-teen pop, r&b, trap queen]
# 216             Skepta                       [hip hop, ohio hip hop, rap]
# 217        DJ+SPINKING                  [melodic rap, pop rap, rap, trap]
#
#        genre
# 0    country
# 1    country
# 2        pop
# 3    country
# 4     hiphop
# ..       ...
# 213   hiphop
# 214      pop
# 215      pop
# 216   hiphop
# 217   hiphop
#
# [193 rows x 3 columns]

# %% [markdown]
# ## Combine genre and event data into one dataframe

# %%
df_merge = pd.merge(df, df_gen, on='artist', how='inner')

# %%
df_merge.head()
# Out:
#   artist                       date  \
# 0  LANCO  Wednesday 16 January 2019
# 1  LANCO     Friday 18 January 2019
# 2  LANCO       Friday 13 March 2020
# 3  LANCO   Saturday 19 January 2019
# 4  LANCO  Saturday 15 February 2020
#
#                                             location  \
# 0    \n      The Depot, Salt Lake City, UT, US\n
# 1        \n      Showbox SoDo, Seattle, WA, US\n
# 2  \n      Joe's Live Rosemont, Rosemont, IL, US\...
# 3    \n      Wonder Ballroom, Portland, OR, US\n
# 4          \n      Bluestone, Columbus, OH, US\n
#
#                          genre_complex    genre
# 0  [contemporary country, country pop]  country
# 1  [contemporary country, country pop]  country
# 2  [contemporary country, country pop]  country
# 3  [contemporary country, country pop]  country
# 4  [contemporary country, country pop]  country

# %%
df_merge.shape
# Out:
# (24651, 5)

# %%
df_merge.to_csv('data/merged.csv', index=False)

# %% [markdown]
# # Data cleaning
# ## Isolate city names

# %%
df_merge = pd.read_csv('data/merged.csv')

# %%
split_data = df_merge["location"].str.split(", ")
data = split_data.to_list()
loc_df = pd.DataFrame(data)
loc_df.head()
# Out:
#                              0               1   2         3     4     5
# 0            \n      The Depot  Salt Lake City  UT  US\n      None  None
# 1         \n      Showbox SoDo         Seattle  WA  US\n      None  None
# 2  \n      Joe's Live Rosemont        Rosemont  IL  US\n      None  None
# 3      \n      Wonder Ballroom        Portland  OR  US\n      None  None
# 4            \n      Bluestone        Columbus  OH  US\n      None  None

# %%
len(loc_df)
# Out:
# 24651

# %%
loc_df[5].value_counts()
# Out:
# US\n            16
# Canada\n         2
# Name: 5, dtype: int64

# %%
loc_df[loc_df[4] is True]
# Out:
# 0                   \n      The Depot
# 1                \n      Showbox SoDo
# 2         \n      Joe's Live Rosemont
# 3             \n      Wonder Ballroom
# 4                   \n      Bluestone
#                      ...
# 24646    \n      The Wellmont Theater
# 24647                \n      S.O.B.'s
# 24648            \n      Tammany Hall
# 24649       \n      Amadeus Nightclub
# 24650            \n      Webster Hall
# Name: 0, Length: 24651, dtype: object

# %% [markdown]
# ### Formatting main location df

# %%
# 716 events had 2 or 3 listed items for the venue, offsetting the columns 
# where the city and country info show up.  Therefore, these must be handled separately

loc_df_4col = loc_df[loc_df[4].isnull()]
len(loc_df_4col)
# Out:
# 23935

# %%
loc_df_4col = loc_df_4col.drop(columns = [4, 5], axis=1)
loc_df_4col.rename(columns={0:'venue', 1:'city', 2:'state', 3:'country'}, inplace=True)
loc_df_4col.head()
# Out:
#                          venue            city state   country
# 0            \n      The Depot  Salt Lake City    UT  US\n
# 1         \n      Showbox SoDo         Seattle    WA  US\n
# 2  \n      Joe's Live Rosemont        Rosemont    IL  US\n
# 3      \n      Wonder Ballroom        Portland    OR  US\n
# 4            \n      Bluestone        Columbus    OH  US\n

# %% [markdown]
# ### Formatting rows with offset city information

# %% [markdown]
# #### 1 column offset

# %%
loc_df_5and6col = loc_df[~loc_df[4].isnull()]

# %%
loc_df_5col = loc_df_5and6col[loc_df_5and6col[5].isnull()]
loc_df_5col
# Out:
#                                     0                         1  \
# 63               \n      GIANT Center              Hershey Park
# 72            \n      EagleBank Arena   George Mason University
# 77     \n      Petersen Events Center  University of Pittsburgh
# 109              \n      Atlanta Room          Smith's Olde Bar
# 114     \n      Thompson-Boling Arena   University of Tennessee
# ...                               ...                       ...
# 24113            \n      The Ballroom            Warehouse Live
# 24151           \n      LIV Nightclub             Fontainebleau
# 24308                \n      Ballroom     Floridan Palace Hotel
# 24387        \n      Rumsey Playfield              Central Park
# 24423             \n      The Shelter         St. Andrew's Hall
#
#                     2   3         4     5
# 63            Hershey  PA  US\n      None
# 72            Fairfax  VA  US\n      None
# 77         Pittsburgh  PA  US\n      None
# 109           Atlanta  GA  US\n      None
# 114         Knoxville  TN  US\n      None
# ...               ...  ..       ...   ...
# 24113         Houston  TX  US\n      None
# 24151     Miami Beach  FL  US\n      None
# 24308           Tampa  FL  US\n      None
# 24387  New York (NYC)  NY  US\n      None
# 24423         Detroit  MI  US\n      None
#
# [698 rows x 6 columns]

# %%
loc_df_5col = loc_df_5col.drop(columns=[1,5])
loc_df_5col.rename(columns={0:'venue', 2:'city', 3:'state', 4:'country'}, inplace=True)
loc_df_5col
# Out:
#                                 venue            city state   country
# 63               \n      GIANT Center         Hershey    PA  US\n
# 72            \n      EagleBank Arena         Fairfax    VA  US\n
# 77     \n      Petersen Events Center      Pittsburgh    PA  US\n
# 109              \n      Atlanta Room         Atlanta    GA  US\n
# 114     \n      Thompson-Boling Arena       Knoxville    TN  US\n
# ...                               ...             ...   ...       ...
# 24113            \n      The Ballroom         Houston    TX  US\n
# 24151           \n      LIV Nightclub     Miami Beach    FL  US\n
# 24308                \n      Ballroom           Tampa    FL  US\n
# 24387        \n      Rumsey Playfield  New York (NYC)    NY  US\n
# 24423             \n      The Shelter         Detroit    MI  US\n
#
# [698 rows x 4 columns]

# %% [markdown]
# #### 2 column offset

# %%
loc_df_6col = loc_df_5and6col[~loc_df_5and6col[5].isnull()]
loc_df_6col
# Out:
#                                    0                                       1  \
# 402                 \n      Red Room                                Cafe 939
# 455                 \n      Red Room                                Cafe 939
# 6078                \n      Red Room                                Cafe 939
# 8090                \n      The Sett                             Union South
# 9853     \n      The Capitol Theatre                            Port Chester
# 10426               \n      Red Room                                Cafe 939
# 11558  \n      Myer Horowitz Theatre                                     SUB
# 13558       \n      Smothers Theatre  Lisa Smith Wengler Center for the Arts
# 15548               \n      Red Room                                Cafe 939
# 16166                \n      Spirits                                    Food
# 16208               \n      Red Room                                Cafe 939
# 16229                \n      Spirits                                    Food
# 16498  \n      Myer Horowitz Theatre                                     SUB
# 20260   \n      Jemison Concert Hall    Alys Stephens Performing Arts Center
# 21392               \n      Red Room                                Cafe 939
# 21394               \n      Red Room                                Cafe 939
# 21439               \n      Red Room                                Cafe 939
# 22320        \n      Der Rathskeller                          Memorial Union
#
#                               2             3   4             5
# 402    Berklee College of Music        Boston  MA      US\n
# 455    Berklee College of Music        Boston  MA      US\n
# 6078   Berklee College of Music        Boston  MA      US\n
# 8090    University of Wisconsin       Madison  WI      US\n
# 9853                         NY  Port Chester  NY      US\n
# 10426  Berklee College of Music        Boston  MA      US\n
# 11558     University of Alberta      Edmonton  AB  Canada\n
# 13558     Pepperdine University        Malibu  CA      US\n
# 15548  Berklee College of Music        Boston  MA      US\n
# 16166               and Friends    Alexandria  LA      US\n
# 16208  Berklee College of Music        Boston  MA      US\n
# 16229               and Friends    Alexandria  LA      US\n
# 16498     University of Alberta      Edmonton  AB  Canada\n
# 20260     University of Alabama    Birmingham  AL      US\n
# 21392  Berklee College of Music        Boston  MA      US\n
# 21394  Berklee College of Music        Boston  MA      US\n
# 21439  Berklee College of Music        Boston  MA      US\n
# 22320   University of Wisconsin       Madison  WI      US\n

# %%
loc_df_6col = loc_df_6col.drop(columns=[1,2])
loc_df_6col.rename(columns={0:'venue', 3:'city', 4:'state', 5:'country'}, inplace=True)
loc_df_6col
# Out:
#                                venue          city state       country
# 402                 \n      Red Room        Boston    MA      US\n
# 455                 \n      Red Room        Boston    MA      US\n
# 6078                \n      Red Room        Boston    MA      US\n
# 8090                \n      The Sett       Madison    WI      US\n
# 9853     \n      The Capitol Theatre  Port Chester    NY      US\n
# 10426               \n      Red Room        Boston    MA      US\n
# 11558  \n      Myer Horowitz Theatre      Edmonton    AB  Canada\n
# 13558       \n      Smothers Theatre        Malibu    CA      US\n
# 15548               \n      Red Room        Boston    MA      US\n
# 16166                \n      Spirits    Alexandria    LA      US\n
# 16208               \n      Red Room        Boston    MA      US\n
# 16229                \n      Spirits    Alexandria    LA      US\n
# 16498  \n      Myer Horowitz Theatre      Edmonton    AB  Canada\n
# 20260   \n      Jemison Concert Hall    Birmingham    AL      US\n
# 21392               \n      Red Room        Boston    MA      US\n
# 21394               \n      Red Room        Boston    MA      US\n
# 21439               \n      Red Room        Boston    MA      US\n
# 22320        \n      Der Rathskeller       Madison    WI      US\n

# %% [markdown]
# ### Combine all location data back into one dataframe and merge with rest of data

# %% [markdown]
# #### Combine location data into one dataframe, sorted by original index #

# %%
comb = pd.concat([loc_df_5col, loc_df_6col], sort=False).sort_index()
comb
# Out:
#                                 venue            city state   country
# 63               \n      GIANT Center         Hershey    PA  US\n
# 72            \n      EagleBank Arena         Fairfax    VA  US\n
# 77     \n      Petersen Events Center      Pittsburgh    PA  US\n
# 109              \n      Atlanta Room         Atlanta    GA  US\n
# 114     \n      Thompson-Boling Arena       Knoxville    TN  US\n
# ...                               ...             ...   ...       ...
# 24113            \n      The Ballroom         Houston    TX  US\n
# 24151           \n      LIV Nightclub     Miami Beach    FL  US\n
# 24308                \n      Ballroom           Tampa    FL  US\n
# 24387        \n      Rumsey Playfield  New York (NYC)    NY  US\n
# 24423             \n      The Shelter         Detroit    MI  US\n
#
# [716 rows x 4 columns]

# %%
combo = pd.concat([loc_df_4col, comb], sort=False).sort_index()
combo
# Out:
#                               venue            city state   country
# 0                 \n      The Depot  Salt Lake City    UT  US\n
# 1              \n      Showbox SoDo         Seattle    WA  US\n
# 2       \n      Joe's Live Rosemont        Rosemont    IL  US\n
# 3           \n      Wonder Ballroom        Portland    OR  US\n
# 4                 \n      Bluestone        Columbus    OH  US\n
# ...                             ...             ...   ...       ...
# 24646  \n      The Wellmont Theater       Montclair    NJ  US\n
# 24647              \n      S.O.B.'s       Manhattan    NY  US\n
# 24648          \n      Tammany Hall  New York (NYC)    NY  US\n
# 24649     \n      Amadeus Nightclub          Queens    NY  US\n
# 24650          \n      Webster Hall  New York (NYC)    NY  US\n
#
# [24651 rows x 4 columns]

# %% [markdown]
# #### Combine location data with artist and genre data

# %%
df_cities = pd.concat([df_merge, combo], axis=1)
df_cities.head()
# Out:
#   artist                       date  \
# 0  LANCO  Wednesday 16 January 2019
# 1  LANCO     Friday 18 January 2019
# 2  LANCO       Friday 13 March 2020
# 3  LANCO   Saturday 19 January 2019
# 4  LANCO  Saturday 15 February 2020
#
#                                             location  \
# 0    \n      The Depot, Salt Lake City, UT, US\n
# 1        \n      Showbox SoDo, Seattle, WA, US\n
# 2  \n      Joe's Live Rosemont, Rosemont, IL, US\...
# 3    \n      Wonder Ballroom, Portland, OR, US\n
# 4          \n      Bluestone, Columbus, OH, US\n
#
#                              genre_complex    genre  \
# 0  ['contemporary country', 'country pop']  country
# 1  ['contemporary country', 'country pop']  country
# 2  ['contemporary country', 'country pop']  country
# 3  ['contemporary country', 'country pop']  country
# 4  ['contemporary country', 'country pop']  country
#
#                          venue            city state   country
# 0            \n      The Depot  Salt Lake City    UT  US\n
# 1         \n      Showbox SoDo         Seattle    WA  US\n
# 2  \n      Joe's Live Rosemont        Rosemont    IL  US\n
# 3      \n      Wonder Ballroom        Portland    OR  US\n
# 4            \n      Bluestone        Columbus    OH  US\n

# %% [markdown]
# ## EDA on list of cities

# %% [markdown]
# #### Filter for US cities

# %%
df_cities['country'].value_counts()
# Out:
# US\n                    18417
# Canada\n                  974
# Australia\n               360
# UK\n                       74
# Germany\n                  36
# Denmark\n                  17
# Netherlands\n              17
# Republic Of\n              12
# New Zealand\n               8
# Ireland\n                   6
# Sweden\n                    4
# Brazil\n                    3
# France\n                    3
# Norway\n                    2
# Japan\n                     2
# Malaysia\n                  2
# Monaco\n                    1
# Macedonia\n                 1
# China\n                     1
# Czech Republic\n            1
# Italy\n                     1
# Switzerland\n               1
# Portugal\n                  1
# Name: country, dtype: int64

# %%
df_uscities = df_cities[df_cities['country'].str.contains("US", na=False)]
df_uscities['country'].value_counts()
# Out:
# US\n        18417
# Name: country, dtype: int64

# %%
df_uscities
# Out:
#             artist                        date  \
# 0            LANCO   Wednesday 16 January 2019
# 1            LANCO      Friday 18 January 2019
# 2            LANCO        Friday 13 March 2020
# 3            LANCO    Saturday 19 January 2019
# 4            LANCO   Saturday 15 February 2020
# ...            ...                         ...
# 24646  DJ+SPINKING    Saturday 12 January 2019
# 24647  DJ+SPINKING        Thursday 14 May 2015
# 24648  DJ+SPINKING     Friday 02 November 2012
# 24649  DJ+SPINKING    Saturday 26 October 2019
# 24650  DJ+SPINKING  Thursday 19 September 2013
#
#                                                 location  \
# 0        \n      The Depot, Salt Lake City, UT, US\n
# 1            \n      Showbox SoDo, Seattle, WA, US\n
# 2      \n      Joe's Live Rosemont, Rosemont, IL, US\...
# 3        \n      Wonder Ballroom, Portland, OR, US\n
# 4              \n      Bluestone, Columbus, OH, US\n
# ...                                                  ...
# 24646  \n      The Wellmont Theater, Montclair, NJ, U...
# 24647          \n      S.O.B.'s, Manhattan, NY, US\n
# 24648  \n      Tammany Hall, New York (NYC), NY, US\n...
# 24649    \n      Amadeus Nightclub, Queens, NY, US\n
# 24650  \n      Webster Hall, New York (NYC), NY, US\n...
#
#                                    genre_complex    genre  \
# 0        ['contemporary country', 'country pop']  country
# 1        ['contemporary country', 'country pop']  country
# 2        ['contemporary country', 'country pop']  country
# 3        ['contemporary country', 'country pop']  country
# 4        ['contemporary country', 'country pop']  country
# ...                                          ...      ...
# 24646  ['melodic rap', 'pop rap', 'rap', 'trap']   hiphop
# 24647  ['melodic rap', 'pop rap', 'rap', 'trap']   hiphop
# 24648  ['melodic rap', 'pop rap', 'rap', 'trap']   hiphop
# 24649  ['melodic rap', 'pop rap', 'rap', 'trap']   hiphop
# 24650  ['melodic rap', 'pop rap', 'rap', 'trap']   hiphop
#
#                               venue            city state   country
# 0                 \n      The Depot  Salt Lake City    UT  US\n
# 1              \n      Showbox SoDo         Seattle    WA  US\n
# 2       \n      Joe's Live Rosemont        Rosemont    IL  US\n
# 3           \n      Wonder Ballroom        Portland    OR  US\n
# 4                 \n      Bluestone        Columbus    OH  US\n
# ...                             ...             ...   ...       ...
# 24646  \n      The Wellmont Theater       Montclair    NJ  US\n
# 24647              \n      S.O.B.'s       Manhattan    NY  US\n
# 24648          \n      Tammany Hall  New York (NYC)    NY  US\n
# 24649     \n      Amadeus Nightclub          Queens    NY  US\n
# 24650          \n      Webster Hall  New York (NYC)    NY  US\n
#
# [18417 rows x 9 columns]

# %%
df_uscities['city'].value_counts()
# Out:
# New York (NYC)      610
# Chicago             543
# Los Angeles (LA)    533
# Atlanta             444
# Philadelphia        419
#                    ...
# Cape Girardeau        1
# Kennett Square        1
# Edinburg              1
# Allegheny County      1
# Pearl                 1
# Name: city, Length: 1068, dtype: int64

# %%
samplesize = []
cutoff = []
citycount = []
for i in range(20,620,20):
    dftest = df_uscities[df_uscities['city'].map(df_uscities['city'].value_counts()) > i]
    length = len(dftest)
    citynum = len(dftest['city'].value_counts())
    samplesize.append(length)
    cutoff.append(i)
    citycount.append(citynum)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.bar(cutoff, citynum)
# Out:
# <BarContainer object of 30 artists>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.bar(cutoff, samplesize)
# Out:
# <BarContainer object of 30 artists>

# %%
dftest = df_uscities[df_uscities['city'].map(df_uscities['city'].value_counts()) < 290]
dftest2 = dftest[dftest['city'].map(dftest['city'].value_counts()) > 50]
dftest2['city'].value_counts()
# Out:
# Minneapolis       288
# Brooklyn          283
# Detroit           245
# San Diego         231
# Las Vegas         205
# Salt Lake City    200
# Charlotte         200
# Columbus          200
# St Louis          182
# Phoenix           170
# Baltimore         163
# Indianapolis      161
# Kansas City       154
# Hollywood         152
# Orlando           151
# Cleveland         149
# Pittsburgh        137
# New Orleans       135
# Santa Ana         132
# Louisville        125
# Milwaukee         125
# Raleigh           121
# Sacramento        118
# San Antonio       114
# Oakland           106
# Cincinnati        106
# Anaheim           105
# Tampa             105
# Birmingham        102
# Jacksonville       99
# Cambridge          98
# Grand Rapids       88
# Richmond           87
# Columbia           84
# West Hollywood     79
# Silver Spring      75
# St. Paul           70
# Omaha              69
# Asbury Park        68
# Albuquerque        68
# Madison            67
# Oklahoma City      66
# Santa Cruz         66
# Buffalo            65
# Athens             65
# Memphis            64
# Norfolk            63
# Miami Beach        63
# Rosemont           61
# San Jose           59
# Pomona             59
# Miami              56
# Greensboro         54
# Berkeley           53
# Morrison           53
# Knoxville          52
# Asheville          52
# Tucson             51
# Tulsa              51
# Name: city, dtype: int64

# %%
# filter dataframe by value_counts value
df1 = df[df['A'].map(df['A'].value_counts()) > 1]

# %%
https://api.songkick.com/api/3.0/search/artists.json?apikey={your_api_key}&query={artist_name}

# %%
import json
import urllib.request

#url = 'https://api.songkick.com/api/3.0/artists/7338694/gigography.json?apikey=X72xzxKFdMGW54Vd&min_date=2018-01-01&max_date=2020-03-01'
#page = requests.get(url)
#soup = json.load(page.read())
#soup

url = 'https://api.songkick.com/api/3.0/artists/7338694/gigography.json?apikey=X72xzxKFdMGW54Vd&min_date=2018-01-01&max_date=2020-03-01&order=asc'
data = urllib.request.urlopen(url).read().decode()

obj = json.loads(data)

# %%
obj['resultsPage']['results']['event'][0]
# Out:
# {'type': 'Concert',
#  'venue': {'displayName': 'Concord Music Hall',
#   'lat': 41.9185623,
#   'lng': -87.6900284,
#   'uri': 'http://www.songkick.com/venues/2375994-concord-music-hall?utm_source=60064&utm_medium=partner',
#   'metroArea': {'displayName': 'Chicago',
#    'country': {'displayName': 'US'},
#    'uri': 'http://www.songkick.com/metro_areas/9426-us-chicago?utm_source=60064&utm_medium=partner',
#    'id': 9426,
#    'state': {'displayName': 'IL'}},
#   'id': 2375994},
#  'status': 'ok',
#  'performance': [{'billing': 'headline',
#    'displayName': 'Kali Uchis',
#    'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#       'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#     'displayName': 'Kali Uchis',
#     'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#     'id': 7338694},
#    'billingIndex': 1,
#    'id': 61875144}],
#  'popularity': 0.023972,
#  'displayName': 'Kali Uchis at Concord Music Hall (January 13, 2018)',
#  'start': {'datetime': '2018-01-13T19:00:00-0600',
#   'time': '19:00:00',
#   'date': '2018-01-13'},
#  'ageRestriction': None,
#  'location': {'city': 'Chicago, IL, US',
#   'lat': 41.9185623,
#   'lng': -87.6900284},
#  'uri': 'http://www.songkick.com/concerts/32101239-kali-uchis-at-concord-music-hall?utm_source=60064&utm_medium=partner',
#  'id': 32101239}

# %%
for i in obj['resultsPage']['results']['event'][0]:
    print(i)
# Out:
# type
# venue
# status
# performance
# popularity
# displayName
# start
# ageRestriction
# location
# uri
# id

# %%
for i in obj['resultsPage']['results']['event']:
    print(i['type'])
# Out:
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Festival
# Concert
# Concert
# Festival
# Concert
# Festival
# Festival
# Concert
# Concert
# Concert
# Festival
# Festival
# Festival
# Concert
# Festival
# Festival
# Festival
# Concert
# Festival
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Concert
# Festival
# Concert
# Concert
# Concert
# Concert

# %%
obj['resultsPage']['results']['event'][0]['type']
# Out:
# 'Concert'

# %%
obj['resultsPage']['results']['event'][0]['location']['city']
# Out:
# 'Chicago, IL, US'

# %%
obj['resultsPage']['results']['event'][0]['popularity']
# Out:
# 0.023972

# %%
obj['resultsPage']['results']['event'][0]['start']['date']
# Out:
# '2018-01-13'

# %%
obj
# Out:
# {'resultsPage': {'status': 'ok',
#   'results': {'event': [{'type': 'Concert',
#      'venue': {'displayName': 'Concord Music Hall',
#       'lat': 41.9185623,
#       'lng': -87.6900284,
#       'uri': 'http://www.songkick.com/venues/2375994-concord-music-hall?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Chicago',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/9426-us-chicago?utm_source=60064&utm_medium=partner',
#        'id': 9426,
#        'state': {'displayName': 'IL'}},
#       'id': 2375994},
#      'status': 'ok',
#      'performance': [{'billing': 'headline',
#        'displayName': 'Kali Uchis',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'billingIndex': 1,
#        'id': 61875144}],
#      'popularity': 0.023972,
#      'displayName': 'Kali Uchis at Concord Music Hall (January 13, 2018)',
#      'start': {'datetime': '2018-01-13T19:00:00-0600',
#       'time': '19:00:00',
#       'date': '2018-01-13'},
#      'ageRestriction': None,
#      'location': {'city': 'Chicago, IL, US',
#       'lat': 41.9185623,
#       'lng': -87.6900284},
#      'uri': 'http://www.songkick.com/concerts/32101239-kali-uchis-at-concord-music-hall?utm_source=60064&utm_medium=partner',
#      'id': 32101239},
#     {'id': 31478459,
#      'displayName': 'Lana Del Rey with Kali Uchis and Jhené Aiko at Scotiabank Arena (January 15, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/31478459-lana-del-rey-at-scotiabank-arena?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.539198,
#      'start': {'date': '2018-01-15',
#       'datetime': '2018-01-15T20:00:00-0500',
#       'time': '20:00:00'},
#      'performance': [{'id': 61002824,
#        'displayName': 'Lana Del Rey',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 2867646,
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json'}]}},
#       {'id': 60818054,
#        'displayName': 'Kali Uchis',
#        'billing': 'support',
#        'billingIndex': 2,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 61002829,
#        'displayName': 'Jhené Aiko',
#        'billing': 'support',
#        'billingIndex': 3,
#        'artist': {'id': 709988,
#         'displayName': 'Jhené Aiko',
#         'uri': 'http://www.songkick.com/artists/709988-jhene-aiko?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'ceb3f5b7-9f1a-430f-afbe-976fdcf30482',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:ceb3f5b7-9f1a-430f-afbe-976fdcf30482.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 3959804,
#       'displayName': 'Scotiabank Arena',
#       'uri': 'http://www.songkick.com/venues/3959804-scotiabank-arena?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Toronto',
#        'country': {'displayName': 'Canada'},
#        'state': {'displayName': 'ON'},
#        'id': 27396,
#        'uri': 'http://www.songkick.com/metro_areas/27396-canada-toronto?utm_source=60064&utm_medium=partner'},
#       'lat': 43.64352,
#       'lng': -79.37908},
#      'location': {'city': 'Toronto, ON, Canada',
#       'lat': 43.64352,
#       'lng': -79.37908}},
#     {'type': 'Concert',
#      'venue': {'displayName': 'Little Caesars Arena',
#       'lat': 42.341949,
#       'lng': -83.054694,
#       'uri': 'http://www.songkick.com/venues/3479984-little-caesars-arena?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Detroit',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/18073-us-detroit?utm_source=60064&utm_medium=partner',
#        'id': 18073,
#        'state': {'displayName': 'MI'}},
#       'id': 3479984},
#      'status': 'ok',
#      'performance': [{'billing': 'headline',
#        'displayName': 'Lana Del Rey',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'billingIndex': 1,
#        'id': 61002884},
#       {'billing': 'support',
#        'displayName': 'Kali Uchis',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'billingIndex': 2,
#        'id': 60801744},
#       {'billing': 'support',
#        'displayName': 'Jhené Aiko',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:ceb3f5b7-9f1a-430f-afbe-976fdcf30482.json',
#           'mbid': 'ceb3f5b7-9f1a-430f-afbe-976fdcf30482'}],
#         'displayName': 'Jhené Aiko',
#         'uri': 'http://www.songkick.com/artists/709988-jhene-aiko?utm_source=60064&utm_medium=partner',
#         'id': 709988},
#        'billingIndex': 3,
#        'id': 61002889}],
#      'popularity': 0.516469,
#      'displayName': 'Lana Del Rey with Kali Uchis and Jhené Aiko at Little Caesars Arena (January 17, 2018)',
#      'start': {'datetime': '2018-01-17T20:00:00-0500',
#       'time': '20:00:00',
#       'date': '2018-01-17'},
#      'ageRestriction': None,
#      'location': {'city': 'Detroit, MI, US',
#       'lat': 42.341949,
#       'lng': -83.054694},
#      'uri': 'http://www.songkick.com/concerts/31468794-lana-del-rey-at-little-caesars-arena?utm_source=60064&utm_medium=partner',
#      'id': 31468794},
#     {'type': 'Concert',
#      'venue': {'displayName': 'Prudential Center',
#       'lat': 40.733747,
#       'lng': -74.170268,
#       'uri': 'http://www.songkick.com/venues/706-prudential-center?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Newark',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/4306-us-newark?utm_source=60064&utm_medium=partner',
#        'id': 4306,
#        'state': {'displayName': 'NJ'}},
#       'id': 706},
#      'status': 'ok',
#      'performance': [{'billing': 'headline',
#        'displayName': 'Lana Del Rey',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'billingIndex': 1,
#        'id': 61003229},
#       {'billing': 'support',
#        'displayName': 'Kali Uchis',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'billingIndex': 2,
#        'id': 60819689},
#       {'billing': 'support',
#        'displayName': 'Jhené Aiko',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:ceb3f5b7-9f1a-430f-afbe-976fdcf30482.json',
#           'mbid': 'ceb3f5b7-9f1a-430f-afbe-976fdcf30482'}],
#         'displayName': 'Jhené Aiko',
#         'uri': 'http://www.songkick.com/artists/709988-jhene-aiko?utm_source=60064&utm_medium=partner',
#         'id': 709988},
#        'billingIndex': 3,
#        'id': 61003234}],
#      'popularity': 0.516631,
#      'displayName': 'Lana Del Rey with Kali Uchis and Jhené Aiko at Prudential Center (January 19, 2018)',
#      'start': {'datetime': '2018-01-19T20:00:00-0500',
#       'time': '20:00:00',
#       'date': '2018-01-19'},
#      'ageRestriction': None,
#      'location': {'city': 'Newark, NJ, US',
#       'lat': 40.733747,
#       'lng': -74.170268},
#      'uri': 'http://www.songkick.com/concerts/31479339-lana-del-rey-at-prudential-center?utm_source=60064&utm_medium=partner',
#      'id': 31479339},
#     {'type': 'Concert',
#      'venue': {'displayName': 'Wells Fargo Center',
#       'lat': 39.9042715,
#       'lng': -75.1713324,
#       'uri': 'http://www.songkick.com/venues/1079871-wells-fargo-center?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Philadelphia',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/5202-us-philadelphia?utm_source=60064&utm_medium=partner',
#        'id': 5202,
#        'state': {'displayName': 'PA'}},
#       'id': 1079871},
#      'status': 'ok',
#      'performance': [{'billing': 'headline',
#        'displayName': 'Lana Del Rey',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'billingIndex': 1,
#        'id': 61003274},
#       {'billing': 'support',
#        'displayName': 'Kali Uchis',
#        'artist': {'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'billingIndex': 2,
#        'id': 60801769}],
#      'popularity': 0.516741,
#      'displayName': 'Lana Del Rey with Kali Uchis at Wells Fargo Center (January 21, 2018)',
#      'start': {'datetime': '2018-01-21T20:00:00-0500',
#       'time': '20:00:00',
#       'date': '2018-01-21'},
#      'ageRestriction': None,
#      'location': {'city': 'Philadelphia, PA, US',
#       'lat': 39.9042715,
#       'lng': -75.1713324},
#      'uri': 'http://www.songkick.com/concerts/31468799-lana-del-rey-at-wells-fargo-center?utm_source=60064&utm_medium=partner',
#      'id': 31468799},
#     {'id': 31479359,
#      'displayName': 'Lana Del Rey with Kali Uchis at Schottenstein Center (January 23, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/31479359-lana-del-rey-at-schottenstein-center?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.543039,
#      'start': {'date': '2018-01-23',
#       'datetime': '2018-01-23T20:00:00-0500',
#       'time': '20:00:00'},
#      'performance': [{'id': 61003299,
#        'displayName': 'Lana Del Rey',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 2867646,
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json'}]}},
#       {'id': 60819729,
#        'displayName': 'Kali Uchis',
#        'billing': 'support',
#        'billingIndex': 2,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 1491,
#       'displayName': 'Schottenstein Center',
#       'uri': 'http://www.songkick.com/venues/1491-schottenstein-center?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Columbus',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'OH'},
#        'id': 9480,
#        'uri': 'http://www.songkick.com/metro_areas/9480-us-columbus?utm_source=60064&utm_medium=partner'},
#       'lat': 40.00801,
#       'lng': -83.02491},
#      'location': {'city': 'Columbus, OH, US',
#       'lat': 40.00801,
#       'lng': -83.02491}},
#     {'type': 'Concert',
#      'popularity': 0.517081,
#      'displayName': 'Lana Del Rey with Kali Uchis and Jhené Aiko at Bryce Jordan Center (January 26, 2018)',
#      'status': 'ok',
#      'performance': [{'displayName': 'Lana Del Rey',
#        'billingIndex': 1,
#        'billing': 'headline',
#        'artist': {'displayName': 'Lana Del Rey',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'id': 61003339},
#       {'displayName': 'Kali Uchis',
#        'billingIndex': 2,
#        'billing': 'support',
#        'artist': {'displayName': 'Kali Uchis',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'id': 60801789},
#       {'displayName': 'Jhené Aiko',
#        'billingIndex': 3,
#        'billing': 'support',
#        'artist': {'displayName': 'Jhené Aiko',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:ceb3f5b7-9f1a-430f-afbe-976fdcf30482.json',
#           'mbid': 'ceb3f5b7-9f1a-430f-afbe-976fdcf30482'}],
#         'uri': 'http://www.songkick.com/artists/709988-jhene-aiko?utm_source=60064&utm_medium=partner',
#         'id': 709988},
#        'id': 60801794}],
#      'ageRestriction': None,
#      'start': {'datetime': '2018-01-26T20:00:00-0500',
#       'time': '20:00:00',
#       'date': '2018-01-26'},
#      'location': {'city': 'University Park, PA, US',
#       'lat': 40.8035111,
#       'lng': -77.8666435},
#      'uri': 'http://www.songkick.com/concerts/31468814-lana-del-rey-at-bryce-jordan-center?utm_source=60064&utm_medium=partner',
#      'id': 31468814,
#      'venue': {'displayName': 'Bryce Jordan Center',
#       'lat': 40.8035111,
#       'lng': -77.8666435,
#       'metroArea': {'displayName': 'Pittsburgh',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/22443-us-pittsburgh?utm_source=60064&utm_medium=partner',
#        'id': 22443,
#        'state': {'displayName': 'PA'}},
#       'uri': 'http://www.songkick.com/venues/1548-bryce-jordan-center?utm_source=60064&utm_medium=partner',
#       'id': 1548}},
#     {'id': 31479379,
#      'displayName': 'Lana Del Rey with Kali Uchis at State Farm Arena (February 5, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/31479379-lana-del-rey-at-state-farm-arena?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.539198,
#      'start': {'date': '2018-02-05',
#       'datetime': '2018-02-05T20:00:00-0500',
#       'time': '20:00:00'},
#      'performance': [{'id': 61003379,
#        'displayName': 'Lana Del Rey',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 2867646,
#         'displayName': 'Lana Del Rey',
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json'}]}},
#       {'id': 60819789,
#        'displayName': 'Kali Uchis',
#        'billing': 'support',
#        'billingIndex': 2,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 4123584,
#       'displayName': 'State Farm Arena',
#       'uri': 'http://www.songkick.com/venues/4123584-state-farm-arena?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Atlanta',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'GA'},
#        'id': 4120,
#        'uri': 'http://www.songkick.com/metro_areas/4120-us-atlanta?utm_source=60064&utm_medium=partner'},
#       'lat': 33.75723,
#       'lng': -84.39634},
#      'location': {'city': 'Atlanta, GA, US',
#       'lat': 33.75723,
#       'lng': -84.39634}},
#     {'type': 'Concert',
#      'popularity': 0.517945,
#      'displayName': 'Lana Del Rey with Kali Uchis at American Airlines Center (February 8, 2018)',
#      'status': 'ok',
#      'performance': [{'displayName': 'Lana Del Rey',
#        'billingIndex': 1,
#        'billing': 'headline',
#        'artist': {'displayName': 'Lana Del Rey',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'id': 61003429},
#       {'displayName': 'Kali Uchis',
#        'billingIndex': 2,
#        'billing': 'support',
#        'artist': {'displayName': 'Kali Uchis',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'id': 60819809}],
#      'ageRestriction': None,
#      'start': {'datetime': '2018-02-08T20:00:00-0600',
#       'time': '20:00:00',
#       'date': '2018-02-08'},
#      'location': {'city': 'Dallas, TX, US',
#       'lat': 32.790442,
#       'lng': -96.810159},
#      'uri': 'http://www.songkick.com/concerts/31479394-lana-del-rey-at-american-airlines-center?utm_source=60064&utm_medium=partner',
#      'id': 31479394,
#      'venue': {'displayName': 'American Airlines Center',
#       'lat': 32.790442,
#       'lng': -96.810159,
#       'metroArea': {'displayName': 'Dallas - Fort Worth',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/35129-us-dallas-fort-worth?utm_source=60064&utm_medium=partner',
#        'id': 35129,
#        'state': {'displayName': 'TX'}},
#       'uri': 'http://www.songkick.com/venues/673-american-airlines-center?utm_source=60064&utm_medium=partner',
#       'id': 673}},
#     {'displayName': 'Lana Del Rey with Kali Uchis at Talking Stick Resort Arena (February 13, 2018)',
#      'type': 'Concert',
#      'status': 'ok',
#      'ageRestriction': None,
#      'start': {'datetime': '2018-02-13T20:00:00-0700',
#       'time': '20:00:00',
#       'date': '2018-02-13'},
#      'location': {'lat': 33.445899,
#       'city': 'Phoenix, AZ, US',
#       'lng': -112.071313},
#      'venue': {'displayName': 'Talking Stick Resort Arena',
#       'lat': 33.445899,
#       'metroArea': {'displayName': 'Phoenix',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/23068-us-phoenix?utm_source=60064&utm_medium=partner',
#        'id': 23068,
#        'state': {'displayName': 'AZ'}},
#       'lng': -112.071313,
#       'uri': 'http://www.songkick.com/venues/613-talking-stick-resort-arena?utm_source=60064&utm_medium=partner',
#       'id': 613},
#      'performance': [{'billing': 'headline',
#        'displayName': 'Lana Del Rey',
#        'billingIndex': 1,
#        'artist': {'displayName': 'Lana Del Rey',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'id': 61004179},
#       {'billing': 'support',
#        'displayName': 'Kali Uchis',
#        'billingIndex': 2,
#        'artist': {'displayName': 'Kali Uchis',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'id': 60819814}],
#      'uri': 'http://www.songkick.com/concerts/31479399-lana-del-rey-at-talking-stick-resort-arena?utm_source=60064&utm_medium=partner',
#      'popularity': 0.518609,
#      'id': 31479399},
#     {'type': 'Concert',
#      'popularity': 0.518543,
#      'displayName': 'Lana Del Rey with Kali Uchis at Valley View Casino Center (February 15, 2018)',
#      'status': 'ok',
#      'performance': [{'displayName': 'Lana Del Rey',
#        'billingIndex': 1,
#        'billing': 'headline',
#        'artist': {'displayName': 'Lana Del Rey',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'id': 61004214},
#       {'displayName': 'Kali Uchis',
#        'billingIndex': 2,
#        'billing': 'support',
#        'artist': {'displayName': 'Kali Uchis',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'id': 60805149}],
#      'ageRestriction': None,
#      'start': {'datetime': '2018-02-15T19:00:00-0800',
#       'time': '19:00:00',
#       'date': '2018-02-15'},
#      'location': {'city': 'San Diego, CA, US',
#       'lat': 32.7550767,
#       'lng': -117.2117942},
#      'uri': 'http://www.songkick.com/concerts/31470499-lana-del-rey-at-valley-view-casino-center?utm_source=60064&utm_medium=partner',
#      'id': 31470499,
#      'venue': {'displayName': 'Valley View Casino Center',
#       'lat': 32.7550767,
#       'lng': -117.2117942,
#       'metroArea': {'displayName': 'San Diego',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/11086-us-san-diego?utm_source=60064&utm_medium=partner',
#        'id': 11086,
#        'state': {'displayName': 'CA'}},
#       'uri': 'http://www.songkick.com/venues/741-valley-view-casino-center?utm_source=60064&utm_medium=partner',
#       'id': 741}},
#     {'type': 'Concert',
#      'popularity': 0.518609,
#      'displayName': 'Lana Del Rey with Kali Uchis at Mandalay Bay Events Center (February 16, 2018)',
#      'status': 'ok',
#      'performance': [{'displayName': 'Lana Del Rey',
#        'billingIndex': 1,
#        'billing': 'headline',
#        'artist': {'displayName': 'Lana Del Rey',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:b7539c32-53e7-4908-bda3-81449c367da6.json',
#           'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6'}],
#         'uri': 'http://www.songkick.com/artists/2867646-lana-del-rey?utm_source=60064&utm_medium=partner',
#         'id': 2867646},
#        'id': 61004309},
#       {'displayName': 'Kali Uchis',
#        'billingIndex': 2,
#        'billing': 'support',
#        'artist': {'displayName': 'Kali Uchis',
#         'identifier': [{'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json',
#           'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d'}],
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'id': 7338694},
#        'id': 60805139}],
#      'ageRestriction': None,
#      'start': {'datetime': '2018-02-16T19:00:00-0800',
#       'time': '19:00:00',
#       'date': '2018-02-16'},
#      'location': {'city': 'Las Vegas, NV, US',
#       'lat': 36.0919655,
#       'lng': -115.1730561},
#      'uri': 'http://www.songkick.com/concerts/31470489-lana-del-rey-at-mandalay-bay-events-center?utm_source=60064&utm_medium=partner',
#      'id': 31470489,
#      'venue': {'displayName': 'Mandalay Bay Events Center',
#       'lat': 36.0919655,
#       'lng': -115.1730561,
#       'metroArea': {'displayName': 'Las Vegas',
#        'country': {'displayName': 'US'},
#        'uri': 'http://www.songkick.com/metro_areas/8396-us-las-vegas?utm_source=60064&utm_medium=partner',
#        'id': 8396,
#        'state': {'displayName': 'NV'}},
#       'uri': 'http://www.songkick.com/venues/554481-mandalay-bay-events-center?utm_source=60064&utm_medium=partner',
#       'id': 554481}},
#     {'id': 32080359,
#      'displayName': 'Kali Uchis at Ace of Spades (February 17, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/32080359-kali-uchis-at-ace-of-spades?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.074938,
#      'start': {'date': '2018-02-17',
#       'datetime': '2018-02-17T19:00:00-0800',
#       'time': '19:00:00'},
#      'performance': [{'id': 61838189,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 1181206,
#       'displayName': 'Ace of Spades',
#       'uri': 'http://www.songkick.com/venues/1181206-ace-of-spades?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Sacramento',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'CA'},
#        'id': 14039,
#        'uri': 'http://www.songkick.com/metro_areas/14039-us-sacramento?utm_source=60064&utm_medium=partner'},
#       'lat': 38.56998,
#       'lng': -121.49069},
#      'location': {'city': 'Sacramento, CA, US',
#       'lat': 38.56998,
#       'lng': -121.49069}},
#     {'id': 32100679,
#      'displayName': 'Kali Uchis and DJ Funklor at Fox Theater - Oakland (February 19, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/32100679-kali-uchis-at-fox-theater-oakland?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.109709,
#      'start': {'date': '2018-02-19',
#       'datetime': '2018-02-19T20:00:00-0800',
#       'time': '20:00:00'},
#      'performance': [{'id': 61874159,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 63260279,
#        'displayName': 'DJ Funklor',
#        'billing': 'headline',
#        'billingIndex': 2,
#        'artist': {'id': 1106647,
#         'displayName': 'DJ Funklor',
#         'uri': 'http://www.songkick.com/artists/1106647-dj-funklor?utm_source=60064&utm_medium=partner',
#         'identifier': []}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 953251,
#       'displayName': 'Fox Theater - Oakland',
#       'uri': 'http://www.songkick.com/venues/953251-fox-theater-oakland?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'SF Bay Area',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'CA'},
#        'id': 26330,
#        'uri': 'http://www.songkick.com/metro-areas/26330-us-sf-bay-area?utm_source=60064&utm_medium=partner'},
#       'lat': 37.80785,
#       'lng': -122.27},
#      'location': {'city': 'Oakland, CA, US', 'lat': 37.80785, 'lng': -122.27}},
#     {'id': 32454209,
#      'displayName': 'Kali Uchis with Cosmo Pyke at Electric Brixton (March 1, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/32454209-kali-uchis-at-electric-brixton?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.109012,
#      'start': {'date': '2018-03-01',
#       'datetime': '2018-03-01T19:00:00+0000',
#       'time': '19:00:00'},
#      'performance': [{'id': 62490359,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 62781194,
#        'displayName': 'Cosmo Pyke',
#        'billing': 'support',
#        'billingIndex': 2,
#        'artist': {'id': 8574369,
#         'displayName': 'Cosmo Pyke',
#         'uri': 'http://www.songkick.com/artists/8574369-cosmo-pyke?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'cf9f891a-59e8-40f5-8efd-26adfcd0d3a7',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:cf9f891a-59e8-40f5-8efd-26adfcd0d3a7.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 9022,
#       'displayName': 'Electric Brixton',
#       'uri': 'http://www.songkick.com/venues/9022-electric-brixton?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'London',
#        'country': {'displayName': 'UK'},
#        'id': 24426,
#        'uri': 'http://www.songkick.com/metro-areas/24426-uk-london?utm_source=60064&utm_medium=partner'},
#       'lat': 51.45995,
#       'lng': -0.11727},
#      'location': {'city': 'London, UK', 'lat': 51.45995, 'lng': -0.11727}},
#     {'id': 31840939,
#      'displayName': 'Vive Latino 2018',
#      'type': 'Festival',
#      'uri': 'https://www.songkick.com/festivals/12951-vive-latino/id/31840939-vive-latino-2018?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.396555,
#      'start': {'date': '2018-03-17', 'datetime': None, 'time': None},
#      'performance': [{'id': 61990394,
#        'displayName': 'Gorillaz',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 68043,
#         'displayName': 'Gorillaz',
#         'uri': 'https://www.songkick.com/artists/68043-gorillaz?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:e21857d5-3256-4547-afb3-4b6ded592596.json'}]}},
#       {'id': 63465399,
#        'displayName': 'Queens of the Stone Age',
#        'billing': 'headline',
#        'billingIndex': 2,
#        'artist': {'id': 479466,
#         'displayName': 'Queens of the Stone Age',
#         'uri': 'https://www.songkick.com/artists/479466-queens-of-the-stone-age?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '7dc8f5bd-9d0b-4087-9f73-dc164950bbd8',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:7dc8f5bd-9d0b-4087-9f73-dc164950bbd8.json'}]}},
#       {'id': 63465149,
#        'displayName': 'Little Dragon',
#        'billing': 'headline',
#        'billingIndex': 3,
#        'artist': {'id': 2561,
#         'displayName': 'Little Dragon',
#         'uri': 'https://www.songkick.com/artists/2561-little-dragon?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'c8a9ae11-63bf-409b-8bf3-a96b3712a2ff',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:c8a9ae11-63bf-409b-8bf3-a96b3712a2ff.json'}]}},
#       {'id': 63465134,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 4,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'https://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 63465189,
#        'displayName': 'Morrissey',
#        'billing': 'headline',
#        'billingIndex': 5,
#        'artist': {'id': 417787,
#         'displayName': 'Morrissey',
#         'uri': 'https://www.songkick.com/artists/417787-morrissey?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '013fa897-86db-41d3-8e9f-386c8a34f4e6',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:013fa897-86db-41d3-8e9f-386c8a34f4e6.json'}]}},
#       {'id': 63465209,
#        'displayName': "Noel Gallagher's High Flying Birds",
#        'billing': 'headline',
#        'billingIndex': 6,
#        'artist': {'id': 4558143,
#         'displayName': "Noel Gallagher's High Flying Birds",
#         'uri': 'https://www.songkick.com/artists/4558143-noel-gallaghers-high-flying-birds?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd5f54887-117b-42a1-9aee-8780b84ebaba',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:d5f54887-117b-42a1-9aee-8780b84ebaba.json'}]}},
#       {'id': 63465314,
#        'displayName': 'Infected Mushroom',
#        'billing': 'headline',
#        'billingIndex': 7,
#        'artist': {'id': 153795,
#         'displayName': 'Infected Mushroom',
#         'uri': 'https://www.songkick.com/artists/153795-infected-mushroom?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'eab76c9f-ff91-4431-b6dd-3b976c598020',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:eab76c9f-ff91-4431-b6dd-3b976c598020.json'}]}},
#       {'id': 63465229,
#        'displayName': 'PVRIS',
#        'billing': 'headline',
#        'billingIndex': 8,
#        'artist': {'id': 7122254,
#         'displayName': 'PVRIS',
#         'uri': 'https://www.songkick.com/artists/7122254-pvris?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'de210c9e-fbf6-4827-987f-dd8885f5d890',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:de210c9e-fbf6-4827-987f-dd8885f5d890.json'}]}},
#       {'id': 63465159,
#        'displayName': 'Molotov',
#        'billing': 'headline',
#        'billingIndex': 9,
#        'artist': {'id': 489691,
#         'displayName': 'Molotov',
#         'uri': 'https://www.songkick.com/artists/489691-molotov?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4f8916d6-a7d2-43e9-96b6-ce3168c39c84',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:4f8916d6-a7d2-43e9-96b6-ce3168c39c84.json'},
#          {'mbid': '7daae91a-caf1-495f-a21a-912ece46501c',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:7daae91a-caf1-495f-a21a-912ece46501c.json'}]}},
#       {'id': 63465269,
#        'displayName': 'Cartel de Santa',
#        'billing': 'headline',
#        'billingIndex': 10,
#        'artist': {'id': 154094,
#         'displayName': 'Cartel de Santa',
#         'uri': 'https://www.songkick.com/artists/154094-cartel-de-santa?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '563f6d35-dbef-403d-aedd-57b5a9250b3d',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:563f6d35-dbef-403d-aedd-57b5a9250b3d.json'}]}},
#       {'id': 63465169,
#        'displayName': 'Los Amigos Invisibles',
#        'billing': 'headline',
#        'billingIndex': 11,
#        'artist': {'id': 290133,
#         'displayName': 'Los Amigos Invisibles',
#         'uri': 'https://www.songkick.com/artists/290133-los-amigos-invisibles?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'c694bf65-83e9-47d5-aeb3-bb68f78ef981',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:c694bf65-83e9-47d5-aeb3-bb68f78ef981.json'}]}},
#       {'id': 63465109,
#        'displayName': 'Chicano Batman',
#        'billing': 'headline',
#        'billingIndex': 12,
#        'artist': {'id': 3600806,
#         'displayName': 'Chicano Batman',
#         'uri': 'https://www.songkick.com/artists/3600806-chicano-batman?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '46efbaa6-1bf3-44b5-8838-67f77d77aa96',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:46efbaa6-1bf3-44b5-8838-67f77d77aa96.json'}]}},
#       {'id': 63465289,
#        'displayName': 'Fito Páez',
#        'billing': 'headline',
#        'billingIndex': 13,
#        'artist': {'id': 428682,
#         'displayName': 'Fito Páez',
#         'uri': 'https://www.songkick.com/artists/428682-fito-paez?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '54bd120a-6bac-4d7c-8b10-ba167bc7e26c',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:54bd120a-6bac-4d7c-8b10-ba167bc7e26c.json'}]}},
#       {'id': 63465434,
#        'displayName': 'Vetusta Morla',
#        'billing': 'headline',
#        'billingIndex': 14,
#        'artist': {'id': 927847,
#         'displayName': 'Vetusta Morla',
#         'uri': 'https://www.songkick.com/artists/927847-vetusta-morla?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'b185451a-9edd-46df-8046-1db7e9594f5a',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:b185451a-9edd-46df-8046-1db7e9594f5a.json'}]}},
#       {'id': 63465374,
#        'displayName': 'Mala Rodríguez',
#        'billing': 'headline',
#        'billingIndex': 15,
#        'artist': {'id': 417950,
#         'displayName': 'Mala Rodríguez',
#         'uri': 'https://www.songkick.com/artists/417950-mala-rodriguez?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '7d6d748f-13fc-4f9c-adc8-087d34c4bdef',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:7d6d748f-13fc-4f9c-adc8-087d34c4bdef.json'}]}},
#       {'id': 63465254,
#        'displayName': 'Panteon Rococo',
#        'billing': 'headline',
#        'billingIndex': 16,
#        'artist': {'id': 113298,
#         'displayName': 'Panteon Rococo',
#         'uri': 'https://www.songkick.com/artists/113298-panteon-rococo?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '8536d91f-d976-4578-9776-9376a004e4f0',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:8536d91f-d976-4578-9776-9376a004e4f0.json'}]}},
#       {'id': 63465194,
#        'displayName': 'Love of Lesbian',
#        'billing': 'headline',
#        'billingIndex': 17,
#        'artist': {'id': 197246,
#         'displayName': 'Love of Lesbian',
#         'uri': 'https://www.songkick.com/artists/197246-love-of-lesbian?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '31ab8f5f-b5d7-41a2-80ef-13084aaf0eab',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:31ab8f5f-b5d7-41a2-80ef-13084aaf0eab.json'}]}},
#       {'id': 63465369,
#        'displayName': 'Los Pericos',
#        'billing': 'headline',
#        'billingIndex': 18,
#        'artist': {'id': 303416,
#         'displayName': 'Los Pericos',
#         'uri': 'https://www.songkick.com/artists/303416-los-pericos?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'fe50841b-f14b-4882-a4be-38a04f69374b',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:fe50841b-f14b-4882-a4be-38a04f69374b.json'}]}},
#       {'id': 63465219,
#        'displayName': 'Nicola Cruz',
#        'billing': 'headline',
#        'billingIndex': 19,
#        'artist': {'id': 5205293,
#         'displayName': 'Nicola Cruz',
#         'uri': 'https://www.songkick.com/artists/5205293-nicola-cruz?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '913ed87d-3b1e-48b8-a3a1-a0377c959b83',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:913ed87d-3b1e-48b8-a3a1-a0377c959b83.json'}]}},
#       {'id': 63465214,
#        'displayName': 'Los Cafres',
#        'billing': 'headline',
#        'billingIndex': 20,
#        'artist': {'id': 481047,
#         'displayName': 'Los Cafres',
#         'uri': 'https://www.songkick.com/artists/481047-los-cafres?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '01310625-d639-4377-afc2-c495f3188b33',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:01310625-d639-4377-afc2-c495f3188b33.json'},
#          {'mbid': '5e2943e7-4b74-438f-9b8a-abfcaa412ec0',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:5e2943e7-4b74-438f-9b8a-abfcaa412ec0.json'}]}},
#       {'id': 62449309,
#        'displayName': 'Gondwana',
#        'billing': 'headline',
#        'billingIndex': 21,
#        'artist': {'id': 149977,
#         'displayName': 'Gondwana',
#         'uri': 'https://www.songkick.com/artists/149977-gondwana?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'c3af32d2-025b-4478-9f26-8b242f4b21cc',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:c3af32d2-025b-4478-9f26-8b242f4b21cc.json'},
#          {'mbid': '26962985-3e12-4f0b-a87e-68306e08b0b5',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:26962985-3e12-4f0b-a87e-68306e08b0b5.json'}]}},
#       {'id': 63465119,
#        'displayName': 'Enjambre',
#        'billing': 'headline',
#        'billingIndex': 22,
#        'artist': {'id': 242707,
#         'displayName': 'Enjambre',
#         'uri': 'https://www.songkick.com/artists/242707-enjambre?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'acc7cb5a-8f3a-4f61-b199-a62d45374dec',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:acc7cb5a-8f3a-4f61-b199-a62d45374dec.json'}]}},
#       {'id': 63465344,
#        'displayName': 'La Gusana Ciega',
#        'billing': 'headline',
#        'billingIndex': 23,
#        'artist': {'id': 49088,
#         'displayName': 'La Gusana Ciega',
#         'uri': 'https://www.songkick.com/artists/49088-la-gusana-ciega?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4db93f32-5462-4fdd-8046-aa925efc5a61',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:4db93f32-5462-4fdd-8046-aa925efc5a61.json'}]}},
#       {'id': 62448479,
#        'displayName': 'La Vela Puerca',
#        'billing': 'headline',
#        'billingIndex': 24,
#        'artist': {'id': 396229,
#         'displayName': 'La Vela Puerca',
#         'uri': 'https://www.songkick.com/artists/396229-la-vela-puerca?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd7fd77f6-ea1f-41db-8858-12a0ae143432',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:d7fd77f6-ea1f-41db-8858-12a0ae143432.json'}]}},
#       {'id': 63465329,
#        'displayName': 'KaseO',
#        'billing': 'headline',
#        'billingIndex': 25,
#        'artist': {'id': 974536,
#         'displayName': 'KaseO',
#         'uri': 'https://www.songkick.com/artists/974536-kaseo?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '68f2f8ac-8ed2-4a42-8d6a-98e679dbc0ae',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:68f2f8ac-8ed2-4a42-8d6a-98e679dbc0ae.json'}]}},
#       {'id': 63465094,
#        'displayName': 'Allison',
#        'billing': 'headline',
#        'billingIndex': 26,
#        'artist': {'id': 248231,
#         'displayName': 'Allison',
#         'uri': 'https://www.songkick.com/artists/248231-allison?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'f5b705c9-875a-4faf-ba32-6d56b994c63f',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:f5b705c9-875a-4faf-ba32-6d56b994c63f.json'},
#          {'mbid': '391432b8-72bb-49a1-8ad7-4c41f342cce0',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:391432b8-72bb-49a1-8ad7-4c41f342cce0.json'},
#          {'mbid': '5a208259-8e28-4da3-ab71-5c333ebf03f3',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:5a208259-8e28-4da3-ab71-5c333ebf03f3.json'},
#          {'mbid': '0bcd8993-77eb-4fab-afb1-cb005a446ed6',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:0bcd8993-77eb-4fab-afb1-cb005a446ed6.json'},
#          {'mbid': '80b915f9-de9a-4efe-9ae0-2ed5b0db2529',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:80b915f9-de9a-4efe-9ae0-2ed5b0db2529.json'}]}},
#       {'id': 63465354,
#        'displayName': 'Las Pastillas Del Abuelo',
#        'billing': 'headline',
#        'billingIndex': 27,
#        'artist': {'id': 529917,
#         'displayName': 'Las Pastillas Del Abuelo',
#         'uri': 'https://www.songkick.com/artists/529917-las-pastillas-del-abuelo?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'b9fbe42f-b54b-4b6a-a107-138c010dbe98',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:b9fbe42f-b54b-4b6a-a107-138c010dbe98.json'}]}},
#       {'id': 61899254,
#        'displayName': 'El Mató a un Policía Motorizado',
#        'billing': 'headline',
#        'billingIndex': 28,
#        'artist': {'id': 47960,
#         'displayName': 'El Mató a un Policía Motorizado',
#         'uri': 'https://www.songkick.com/artists/47960-el-mato-a-un-policia-motorizado?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '9eaf4321-20b8-4611-bc82-493a361104e3',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:9eaf4321-20b8-4611-bc82-493a361104e3.json'}]}},
#       {'id': 61464319,
#        'displayName': 'Airbag',
#        'billing': 'headline',
#        'billingIndex': 29,
#        'artist': {'id': 388301,
#         'displayName': 'Airbag',
#         'uri': 'https://www.songkick.com/artists/388301-airbag?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '085dd571-46fc-4a0b-aa74-b6f05d588c7e',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:085dd571-46fc-4a0b-aa74-b6f05d588c7e.json'},
#          {'mbid': 'fa8ec1e9-6020-4478-b939-cf5c80fec696',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:fa8ec1e9-6020-4478-b939-cf5c80fec696.json'},
#          {'mbid': '4d17e1e5-5fe8-461b-ab80-12364e430b67',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:4d17e1e5-5fe8-461b-ab80-12364e430b67.json'},
#          {'mbid': '5ff525f0-a7ed-41ba-ba01-f88ebd2df482',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:5ff525f0-a7ed-41ba-ba01-f88ebd2df482.json'},
#          {'mbid': '2449e126-0046-4457-93a1-42b6425cb63d',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:2449e126-0046-4457-93a1-42b6425cb63d.json'}]}},
#       {'id': 63465384,
#        'displayName': 'Pussy Riot',
#        'billing': 'headline',
#        'billingIndex': 30,
#        'artist': {'id': 5387358,
#         'displayName': 'Pussy Riot',
#         'uri': 'https://www.songkick.com/artists/5387358-pussy-riot?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '631e3bc5-428a-432b-87f7-5d357a007fc0',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:631e3bc5-428a-432b-87f7-5d357a007fc0.json'}]}},
#       {'id': 63465104,
#        'displayName': 'Camilo Séptimo',
#        'billing': 'headline',
# ...
#       'lat': 33.45141,
#       'lng': -112.07819},
#      'location': {'city': 'Phoenix, AZ, US',
#       'lat': 33.45141,
#       'lng': -112.07819}},
#     {'id': 34375424,
#      'displayName': 'Kali Uchis with Gabriel Garzón-Montano at The Bomb Factory (September 25, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/34375424-kali-uchis-at-bomb-factory?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.109322,
#      'start': {'date': '2018-09-25',
#       'datetime': '2018-09-25T21:00:00-0500',
#       'time': '21:00:00'},
#      'performance': [{'id': 65966109,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 66760904,
#        'displayName': 'Gabriel Garzón-Montano',
#        'billing': 'support',
#        'billingIndex': 2,
#        'artist': {'id': 6969044,
#         'displayName': 'Gabriel Garzón-Montano',
#         'uri': 'http://www.songkick.com/artists/6969044-gabriel-garzonmontano?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4cc212e1-0c06-4675-9c8b-bf6c4fb05769',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:4cc212e1-0c06-4675-9c8b-bf6c4fb05769.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 45544,
#       'displayName': 'The Bomb Factory',
#       'uri': 'http://www.songkick.com/venues/45544-bomb-factory?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Dallas - Fort Worth',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'TX'},
#        'id': 35129,
#        'uri': 'http://www.songkick.com/metro-areas/35129-us-dallas-fort-worth?utm_source=60064&utm_medium=partner'},
#       'lat': 32.78229,
#       'lng': -96.78416},
#      'location': {'city': 'Dallas, TX, US',
#       'lat': 32.78229,
#       'lng': -96.78416}},
#     {'id': 35071024,
#      'displayName': "Kali Uchis and Gabriel Garzón-Montano at Stubb's Barbeque (September 27, 2018)",
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/35071024-kali-uchis-at-stubbs-barbeque?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.054459,
#      'start': {'date': '2018-09-27',
#       'datetime': '2018-09-27T19:00:00-0500',
#       'time': '19:00:00'},
#      'performance': [{'id': 67185719,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 67185724,
#        'displayName': 'Gabriel Garzón-Montano',
#        'billing': 'headline',
#        'billingIndex': 2,
#        'artist': {'id': 6969044,
#         'displayName': 'Gabriel Garzón-Montano',
#         'uri': 'http://www.songkick.com/artists/6969044-gabriel-garzonmontano?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4cc212e1-0c06-4675-9c8b-bf6c4fb05769',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:4cc212e1-0c06-4675-9c8b-bf6c4fb05769.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 4012414,
#       'displayName': "Stubb's Barbeque",
#       'uri': 'http://www.songkick.com/venues/4012414-stubbs-barbeque?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Austin',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'TX'},
#        'id': 9179,
#        'uri': 'http://www.songkick.com/metro_areas/9179-us-austin?utm_source=60064&utm_medium=partner'},
#       'lat': 30.27292,
#       'lng': -97.74439},
#      'location': {'city': 'Austin, TX, US',
#       'lat': 30.27292,
#       'lng': -97.74439}},
#     {'id': 34374904,
#      'displayName': 'Kali Uchis at House of Blues - Houston (September 28, 2018)',
#      'type': 'Concert',
#      'uri': 'https://www.songkick.com/concerts/34374904-kali-uchis-at-house-of-blues-houston?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.110865,
#      'start': {'date': '2018-09-28',
#       'datetime': '2018-09-28T19:00:00-0500',
#       'time': '19:00:00'},
#      'performance': [{'id': 65965314,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'https://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'https://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 30866,
#       'displayName': 'House of Blues - Houston',
#       'uri': 'https://www.songkick.com/venues/30866-house-of-blues-houston?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Houston',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'TX'},
#        'id': 15073,
#        'uri': 'https://www.songkick.com/metro-areas/15073-us-houston?utm_source=60064&utm_medium=partner'},
#       'lat': 29.75393,
#       'lng': -95.36406},
#      'location': {'city': 'Houston, TX, US',
#       'lat': 29.75393,
#       'lng': -95.36406}},
#     {'id': 35121464,
#      'displayName': 'LA Phil 100 at the Bowl 2018',
#      'type': 'Festival',
#      'uri': 'http://www.songkick.com/festivals/2590279-la-phil-100-at-the-bowl/id/35121464-la-phil-100-at-the-bowl-2018?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.717513,
#      'start': {'date': '2018-09-30', 'datetime': None, 'time': None},
#      'performance': [{'id': 67309349,
#        'displayName': 'Katy Perry',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 1134363,
#         'displayName': 'Katy Perry',
#         'uri': 'http://www.songkick.com/artists/1134363-katy-perry?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '122d63fc-8671-43e4-9752-34e846d62a9c',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:122d63fc-8671-43e4-9752-34e846d62a9c.json'}]}},
#       {'id': 67309359,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 2,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 67309354,
#        'displayName': 'Herbie Hancock',
#        'billing': 'headline',
#        'billingIndex': 3,
#        'artist': {'id': 224916,
#         'displayName': 'Herbie Hancock',
#         'uri': 'http://www.songkick.com/artists/224916-herbie-hancock?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '27613b78-1b9d-4ec3-9db5-fa0743465fdd',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:27613b78-1b9d-4ec3-9db5-fa0743465fdd.json'}]}},
#       {'id': 67309344,
#        'displayName': 'Gustavo Dudamel',
#        'billing': 'headline',
#        'billingIndex': 4,
#        'artist': {'id': 580721,
#         'displayName': 'Gustavo Dudamel',
#         'uri': 'http://www.songkick.com/artists/580721-gustavo-dudamel?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4c8702d6-86f9-4ef0-a9ee-08042481c542',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:4c8702d6-86f9-4ef0-a9ee-08042481c542.json'}]}},
#       {'id': 67309364,
#        'displayName': 'Youth Orchestra Los Angeles (YOLA)',
#        'billing': 'headline',
#        'billingIndex': 5,
#        'artist': {'id': 9657859,
#         'displayName': 'Youth Orchestra Los Angeles (YOLA)',
#         'uri': 'http://www.songkick.com/artists/9657859-youth-orchestra-los-angeles-yola?utm_source=60064&utm_medium=partner',
#         'identifier': []}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 7211,
#       'displayName': 'Hollywood Bowl',
#       'uri': 'http://www.songkick.com/venues/7211-hollywood-bowl?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Los Angeles',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'CA'},
#        'id': 17835,
#        'uri': 'http://www.songkick.com/metro_areas/17835-us-los-angeles?utm_source=60064&utm_medium=partner'},
#       'lat': 34.11137,
#       'lng': -118.33624},
#      'location': {'city': 'Hollywood, CA, US',
#       'lat': 34.11137,
#       'lng': -118.33624},
#      'end': {'date': '2018-09-30', 'time': None, 'datetime': None},
#      'series': {'displayName': 'LA Phil 100 at the Bowl'}},
#     {'id': 34375444,
#      'displayName': 'Kali Uchis at The Beacham (October 2, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/34375444-kali-uchis-at-beacham?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.055066,
#      'start': {'date': '2018-10-02',
#       'datetime': '2018-10-02T18:00:00-0400',
#       'time': '18:00:00'},
#      'performance': [{'id': 65966129,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 43964,
#       'displayName': 'The Beacham',
#       'uri': 'http://www.songkick.com/venues/43964-beacham?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Orlando',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'FL'},
#        'id': 3733,
#        'uri': 'http://www.songkick.com/metro_areas/3733-us-orlando?utm_source=60064&utm_medium=partner'},
#       'lat': 28.54297,
#       'lng': -81.37938},
#      'location': {'city': 'Orlando, FL, US',
#       'lat': 28.54297,
#       'lng': -81.37938}},
#     {'id': 34374949,
#      'displayName': 'Kali Uchis at Revolution Live (October 3, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/34374949-kali-uchis-at-revolution-live?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.055212,
#      'start': {'date': '2018-10-03',
#       'datetime': '2018-10-03T19:00:00-0400',
#       'time': '19:00:00'},
#      'performance': [{'id': 65965369,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 408111,
#       'displayName': 'Revolution Live',
#       'uri': 'http://www.songkick.com/venues/408111-revolution-live?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Fort Lauderdale',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'FL'},
#        'id': 19511,
#        'uri': 'http://www.songkick.com/metro_areas/19511-us-fort-lauderdale?utm_source=60064&utm_medium=partner'},
#       'lat': 26.12118,
#       'lng': -80.14633},
#      'location': {'city': 'Fort Lauderdale, FL, US',
#       'lat': 26.12118,
#       'lng': -80.14633}},
#     {'id': 34374969,
#      'displayName': 'Kali Uchis at Tabernacle (October 5, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/34374969-kali-uchis-at-tabernacle?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.109709,
#      'start': {'date': '2018-10-05',
#       'datetime': '2018-10-05T20:00:00-0400',
#       'time': '20:00:00'},
#      'performance': [{'id': 65965394,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 669,
#       'displayName': 'Tabernacle',
#       'uri': 'http://www.songkick.com/venues/669-tabernacle?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Atlanta',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'GA'},
#        'id': 4120,
#        'uri': 'http://www.songkick.com/metro-areas/4120-us-atlanta?utm_source=60064&utm_medium=partner'},
#       'lat': 33.7587,
#       'lng': -84.39146},
#      'location': {'city': 'Atlanta, GA, US',
#       'lat': 33.7587,
#       'lng': -84.39146}},
#     {'id': 34374994,
#      'displayName': 'Kali Uchis and Gabriel Garzón-Montano at The Fillmore (October 6, 2018)',
#      'type': 'Concert',
#      'uri': 'http://www.songkick.com/concerts/34374994-kali-uchis-at-fillmore?utm_source=60064&utm_medium=partner',
#      'status': 'ok',
#      'popularity': 0.108306,
#      'start': {'date': '2018-10-06',
#       'datetime': '2018-10-06T20:00:00-0400',
#       'time': '20:00:00'},
#      'performance': [{'id': 65965424,
#        'displayName': 'Kali Uchis',
#        'billing': 'headline',
#        'billingIndex': 1,
#        'artist': {'id': 7338694,
#         'displayName': 'Kali Uchis',
#         'uri': 'http://www.songkick.com/artists/7338694-kali-uchis?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': 'd0c7656d-8169-4f77-9dbe-b8f24e40105d',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:d0c7656d-8169-4f77-9dbe-b8f24e40105d.json'}]}},
#       {'id': 65965429,
#        'displayName': 'Gabriel Garzón-Montano',
#        'billing': 'headline',
#        'billingIndex': 2,
#        'artist': {'id': 6969044,
#         'displayName': 'Gabriel Garzón-Montano',
#         'uri': 'http://www.songkick.com/artists/6969044-gabriel-garzonmontano?utm_source=60064&utm_medium=partner',
#         'identifier': [{'mbid': '4cc212e1-0c06-4675-9c8b-bf6c4fb05769',
#           'href': 'http://api.songkick.com/api/3.0/artists/mbid:4cc212e1-0c06-4675-9c8b-bf6c4fb05769.json'}]}}],
#      'ageRestriction': None,
#      'flaggedAsEnded': True,
#      'venue': {'id': 68889,
#       'displayName': 'The Fillmore',
#       'uri': 'http://www.songkick.com/venues/68889-fillmore?utm_source=60064&utm_medium=partner',
#       'metroArea': {'displayName': 'Charlotte',
#        'country': {'displayName': 'US'},
#        'state': {'displayName': 'NC'},
#        'id': 13579,
#        'uri': 'http://www.songkick.com/metro-areas/13579-us-charlotte?utm_source=60064&utm_medium=partner'},
#       'lat': 35.23942,
#       'lng': -80.84584},
#      'location': {'city': 'Charlotte, NC, US',
#       'lat': 35.23942,
#       'lng': -80.84584}}]},
#   'perPage': 50,
#   'page': 1,
#   'totalEntries': 104}}

# %%
https://api.songkick.com/api/3.0/artists/{artist_id}/gigography.json?apikey={your_api_key}
